# %%
import matplotlib.pyplot as plt
import math

# Energy absorption between FLayer and Back
# Velocity (x) of FLayer
# 1. stage 1; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage1-case1-sq123_s2_50/abq_run/Job-1_v1_n2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
v1_n2_Fr_s1c1 = [0.001*float(item[1]) for item in data2]
# 2. stage 3; case 1; CMP == 132
with open('../2_CPM_Comp_Impact/stage3-case1-sq132_s2_50/abq_run/Job-1_v1_n2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Fr_s3c1 = [0.001*float(item[1]) for item in data2]
# 3. stage 3; case 2; PCM == 213
with open('../2_CPM_Comp_Impact/stage3-case2-sq213_s2_50/abq_run/Job-1_v1_n2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Fr_s3c2 = [0.001*float(item[1]) for item in data2]
# 4. stage 3; case 3; PMC == 231
with open('../2_CPM_Comp_Impact/stage3-case3-sq231_s2_50/abq_run/Job-1_v1_n2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Fr_s3c3 = [0.001*float(item[1]) for item in data2]
# 5. stage 3; case 4; MCP == 312
with open('../2_CPM_Comp_Impact/stage3-case4-sq312_s2_50/abq_run/Job-1_v1_n2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Fr_s3c4 = [0.001*float(item[1]) for item in data2]
# 6. stage 3; case 5; MPC == 321
with open('../2_CPM_Comp_Impact/stage3-case5-sq321_s2_50/abq_run/Job-1_v1_n2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Fr_s3c5 = [0.001*float(item[1]) for item in data2]

# Stress (xx) of FLayer
# 1. stage 1; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage1-case1-sq123_s2_50/abq_run/Job-1_s11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Fr_s1c1 = [float(item[1]) for item in data2]
# 2. stage 3; case 1; CMP == 132
with open('../2_CPM_Comp_Impact/stage3-case1-sq132_s2_50/abq_run/Job-1_s11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Fr_s3c1 = [float(item[1]) for item in data2]
# 3. stage 3; case 2; PCM == 213
with open('../2_CPM_Comp_Impact/stage3-case2-sq213_s2_50/abq_run/Job-1_s11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Fr_s3c2 = [float(item[1]) for item in data2]
# 4. stage 3; case 3; PMC == 231
with open('../2_CPM_Comp_Impact/stage3-case3-sq231_s2_50/abq_run/Job-1_s11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Fr_s3c3 = [float(item[1]) for item in data2]
# 5. stage 3; case 4; MCP == 312
with open('../2_CPM_Comp_Impact/stage3-case4-sq312_s2_50/abq_run/Job-1_s11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Fr_s3c4 = [float(item[1]) for item in data2]
# 6. stage 3; case 5; MPC == 321
with open('../2_CPM_Comp_Impact/stage3-case5-sq321_s2_50/abq_run/Job-1_s11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Fr_s3c5 = [float(item[1]) for item in data2]

# Strain (xx) of FLayer (logarithmic)
# 1. stage 1; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage1-case1-sq123_s2_50/abq_run/Job-1_le11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Fr_s1c1 = [float(item[1]) for item in data2]
# 2. stage 3; case 1; CMP == 132
with open('../2_CPM_Comp_Impact/stage3-case1-sq132_s2_50/abq_run/Job-1_le11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Fr_s3c1 = [float(item[1]) for item in data2]
# 3. stage 3; case 2; PCM == 213
with open('../2_CPM_Comp_Impact/stage3-case2-sq213_s2_50/abq_run/Job-1_le11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Fr_s3c2 = [float(item[1]) for item in data2]
# 4. stage 3; case 3; PMC == 231
with open('../2_CPM_Comp_Impact/stage3-case3-sq231_s2_50/abq_run/Job-1_le11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Fr_s3c3 = [float(item[1]) for item in data2]
# 5. stage 3; case 4; MCP == 312
with open('../2_CPM_Comp_Impact/stage3-case4-sq312_s2_50/abq_run/Job-1_le11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Fr_s3c4 = [float(item[1]) for item in data2]
# 6. stage 3; case 5; MPC == 321
with open('../2_CPM_Comp_Impact/stage3-case5-sq321_s2_50/abq_run/Job-1_le11_e2_Fr.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Fr_s3c5 = [float(item[1]) for item in data2]

# Velocity (x) of Back
# 1. stage 1; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage1-case1-sq123_s2_50/abq_run/Job-1_v1_n2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bk_s1c1 = [0.001*float(item[1]) for item in data2]
# 2. stage 3; case 1; CMP == 132
with open('../2_CPM_Comp_Impact/stage3-case1-sq132_s2_50/abq_run/Job-1_v1_n2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bk_s3c1 = [0.001*float(item[1]) for item in data2]
# 3. stage 3; case 2; PCM == 213
with open('../2_CPM_Comp_Impact/stage3-case2-sq213_s2_50/abq_run/Job-1_v1_n2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bk_s3c2 = [0.001*float(item[1]) for item in data2]
# 4. stage 3; case 3; PMC == 231
with open('../2_CPM_Comp_Impact/stage3-case3-sq231_s2_50/abq_run/Job-1_v1_n2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bk_s3c3 = [0.001*float(item[1]) for item in data2]
# 5. stage 3; case 4; MCP == 312
with open('../2_CPM_Comp_Impact/stage3-case4-sq312_s2_50/abq_run/Job-1_v1_n2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bk_s3c4 = [0.001*float(item[1]) for item in data2]
# 6. stage 3; case 5; MPC == 321
with open('../2_CPM_Comp_Impact/stage3-case5-sq321_s2_50/abq_run/Job-1_v1_n2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bk_s3c5 = [0.001*float(item[1]) for item in data2]

# Stress (xx) of Back
# 1. stage 1; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage1-case1-sq123_s2_50/abq_run/Job-1_s11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bk_s1c1 = [float(item[1]) for item in data2]
# 2. stage 3; case 1; CMP == 132
with open('../2_CPM_Comp_Impact/stage3-case1-sq132_s2_50/abq_run/Job-1_s11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bk_s3c1 = [float(item[1]) for item in data2]
# 3. stage 3; case 2; PCM == 213
with open('../2_CPM_Comp_Impact/stage3-case2-sq213_s2_50/abq_run/Job-1_s11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bk_s3c2 = [float(item[1]) for item in data2]
# 4. stage 3; case 3; PMC == 231
with open('../2_CPM_Comp_Impact/stage3-case3-sq231_s2_50/abq_run/Job-1_s11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bk_s3c3 = [float(item[1]) for item in data2]
# 5. stage 3; case 4; MCP == 312
with open('../2_CPM_Comp_Impact/stage3-case4-sq312_s2_50/abq_run/Job-1_s11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bk_s3c4 = [float(item[1]) for item in data2]
# 6. stage 3; case 5; MPC == 321
with open('../2_CPM_Comp_Impact/stage3-case5-sq321_s2_50/abq_run/Job-1_s11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bk_s3c5 = [float(item[1]) for item in data2]

# Strain (xx) of Back (logarithmic)
# 1. stage 1; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage1-case1-sq123_s2_50/abq_run/Job-1_le11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Bk_s1c1 = [float(item[1]) for item in data2]
# 2. stage 3; case 1; CMP == 132
with open('../2_CPM_Comp_Impact/stage3-case1-sq132_s2_50/abq_run/Job-1_le11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Bk_s3c1 = [float(item[1]) for item in data2]
# 3. stage 3; case 2; PCM == 213
with open('../2_CPM_Comp_Impact/stage3-case2-sq213_s2_50/abq_run/Job-1_le11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Bk_s3c2 = [float(item[1]) for item in data2]
# 4. stage 3; case 3; PMC == 231
with open('../2_CPM_Comp_Impact/stage3-case3-sq231_s2_50/abq_run/Job-1_le11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Bk_s3c3 = [float(item[1]) for item in data2]
# 5. stage 3; case 4; MCP == 312
with open('../2_CPM_Comp_Impact/stage3-case4-sq312_s2_50/abq_run/Job-1_le11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Bk_s3c4 = [float(item[1]) for item in data2]
# 6. stage 3; case 5; MPC == 321
with open('../2_CPM_Comp_Impact/stage3-case5-sq321_s2_50/abq_run/Job-1_le11_e2_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_Bk_s3c5 = [float(item[1]) for item in data2]

# Potential energy: 0.5*(0.2*0.2*0.1*1e-9)*s11*(1e+6)*(exp(le11)-1)*(1e+6) (μJ)
PE_Fr_s1c1 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Fr_s1c1[i])*1e+6*(math.exp(le11_e2_Fr_s1c1[i])-1)*(1e+6) for i in range(len(s11_e2_Fr_s1c1))]
PE_Fr_s3c1 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Fr_s3c1[i])*1e+6*(math.exp(le11_e2_Fr_s3c1[i])-1)*(1e+6) for i in range(len(s11_e2_Fr_s3c1))]
PE_Fr_s3c2 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Fr_s3c2[i])*1e+6*(math.exp(le11_e2_Fr_s3c2[i])-1)*(1e+6) for i in range(len(s11_e2_Fr_s3c2))]
PE_Fr_s3c3 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Fr_s3c3[i])*1e+6*(math.exp(le11_e2_Fr_s3c3[i])-1)*(1e+6) for i in range(len(s11_e2_Fr_s3c3))]
PE_Fr_s3c4 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Fr_s3c4[i])*1e+6*(math.exp(le11_e2_Fr_s3c4[i])-1)*(1e+6) for i in range(len(s11_e2_Fr_s3c4))]
PE_Fr_s3c5 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Fr_s3c5[i])*1e+6*(math.exp(le11_e2_Fr_s3c5[i])-1)*(1e+6) for i in range(len(s11_e2_Fr_s3c5))]
PE_Bk_s1c1 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Bk_s1c1[i])*1e+6*(math.exp(le11_e2_Bk_s1c1[i])-1)*(1e+6) for i in range(len(s11_e2_Bk_s1c1))]
PE_Bk_s3c1 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Bk_s3c1[i])*1e+6*(math.exp(le11_e2_Bk_s3c1[i])-1)*(1e+6) for i in range(len(s11_e2_Bk_s3c1))]
PE_Bk_s3c2 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Bk_s3c2[i])*1e+6*(math.exp(le11_e2_Bk_s3c2[i])-1)*(1e+6) for i in range(len(s11_e2_Bk_s3c2))]
PE_Bk_s3c3 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Bk_s3c3[i])*1e+6*(math.exp(le11_e2_Bk_s3c3[i])-1)*(1e+6) for i in range(len(s11_e2_Bk_s3c3))]
PE_Bk_s3c4 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Bk_s3c4[i])*1e+6*(math.exp(le11_e2_Bk_s3c4[i])-1)*(1e+6) for i in range(len(s11_e2_Bk_s3c4))]
PE_Bk_s3c5 = [0.5*(0.2*0.2*0.1*1e-9)*(s11_e2_Bk_s3c5[i])*1e+6*(math.exp(le11_e2_Bk_s3c5[i])-1)*(1e+6) for i in range(len(s11_e2_Bk_s3c5))]
# Kinetic energy: 0.5*(7830*0.2*0.2*0.1*1e-9)*v1^2*(1e+6) (μJ)
KE_Fr_s1c1 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Fr_s1c1[i]*v1_n2_Fr_s1c1[i]*(1e+6) for i in range(len(v1_n2_Fr_s1c1))]
KE_Fr_s3c1 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Fr_s3c1[i]*v1_n2_Fr_s3c1[i]*(1e+6) for i in range(len(v1_n2_Fr_s3c1))]
KE_Fr_s3c2 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Fr_s3c2[i]*v1_n2_Fr_s3c2[i]*(1e+6) for i in range(len(v1_n2_Fr_s3c2))]
KE_Fr_s3c3 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Fr_s3c3[i]*v1_n2_Fr_s3c3[i]*(1e+6) for i in range(len(v1_n2_Fr_s3c3))]
KE_Fr_s3c4 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Fr_s3c4[i]*v1_n2_Fr_s3c4[i]*(1e+6) for i in range(len(v1_n2_Fr_s3c4))]
KE_Fr_s3c5 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Fr_s3c5[i]*v1_n2_Fr_s3c5[i]*(1e+6) for i in range(len(v1_n2_Fr_s3c5))]
KE_Bk_s1c1 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Bk_s1c1[i]*v1_n2_Bk_s1c1[i]*(1e+6) for i in range(len(v1_n2_Bk_s1c1))]
KE_Bk_s3c1 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Bk_s3c1[i]*v1_n2_Bk_s3c1[i]*(1e+6) for i in range(len(v1_n2_Bk_s3c1))]
KE_Bk_s3c2 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Bk_s3c2[i]*v1_n2_Bk_s3c2[i]*(1e+6) for i in range(len(v1_n2_Bk_s3c2))]
KE_Bk_s3c3 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Bk_s3c3[i]*v1_n2_Bk_s3c3[i]*(1e+6) for i in range(len(v1_n2_Bk_s3c3))]
KE_Bk_s3c4 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Bk_s3c4[i]*v1_n2_Bk_s3c4[i]*(1e+6) for i in range(len(v1_n2_Bk_s3c4))]
KE_Bk_s3c5 = [0.5*(7830*0.2*0.2*0.1*1e-9)*v1_n2_Bk_s3c5[i]*v1_n2_Bk_s3c5[i]*(1e+6) for i in range(len(v1_n2_Bk_s3c5))]

# %%
# Figure 7(a)
fig1,ax1 = plt.subplots(layout = 'constrained',figsize=(5,8))
ax1.plot(time[0:201],PE_Fr_s1c1[0:201],linewidth=4,color='tab:pink',label='C as the first layer')
#ax1.plot(time[0:271],PE_Fr_s3c1[0:271],linewidth=2,color='tab:orange',label='CMP, 132')
ax1.plot(time[0:201],PE_Fr_s3c2[0:201],linewidth=4,color='tab:olive',label='P as the first layer')
#ax1.plot(time[0:271],PE_Fr_s3c3[0:271],linewidth=2,color='tab:red',label='PMC, 231')
ax1.plot(time[0:201],PE_Fr_s3c4[0:201],linewidth=4,color='tab:cyan',label='M as the first layer')
#ax1.plot(time[0:271],PE_Fr_s3c5[0:271],linewidth=2,color='tab:brown',label='MPC, 321')
ax1.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=20)
ax1.set_ylabel('Element strain energy ($\\rm{\mu J}$)',fontsize=20)
ax1.set_xlim(0,2.1)
ax1.set_ylim(0,41)
ax1.set_xticks([0,0.5,1,1.5,2.0])
ax1.set_xticklabels(['0','0.5','1','1.5','2'],fontsize=18)
ax1.set_yticks([0,10,20,30,40])
ax1.set_yticklabels(['0','10','20','30','40'],fontsize=18)
legend = ax1.legend(loc='upper right',fontsize=16)
# fig1.savefig('Figure7a1.png', dpi=1200)

w = 0.3/2
g = 0.02
h = 0.6*w
bar_y = [1+10*w+5*g,1+8*w+4*g,1+6*w+3*g,1+4*w+2*g,1+2*w+g,1]
PE_Bk = [max(PE_Bk_s1c1[600:1100]),
         max(PE_Bk_s3c1[600:1100]),
         max(PE_Bk_s3c2[600:1100]),
         max(PE_Bk_s3c3[600:1100]),
         max(PE_Bk_s3c4[600:1100]),
         max(PE_Bk_s3c5[600:1100])]
fig2,ax2 = plt.subplots(layout = 'constrained',figsize=(5,8)) # 9,5.4
# ax2.yaxis.tick_right()
# ax2.yaxis.set_label_position('right')
bh1 = ax2.barh(bar_y[2],PE_Bk[0],align='center',height=2*h,linewidth=0,edgecolor='tab:blue',color='tab:blue')
bh2 = ax2.barh(bar_y[4],PE_Bk[1],align='center',height=2*h,linewidth=0,edgecolor='tab:orange',color='tab:orange')
bh3 = ax2.barh(bar_y[3],PE_Bk[2],align='center',height=2*h,linewidth=0,edgecolor='tab:green',color='tab:green')
bh4 = ax2.barh(bar_y[5],PE_Bk[3],align='center',height=2*h,linewidth=0,edgecolor='tab:red',color='tab:red')
bh5 = ax2.barh(bar_y[1],PE_Bk[4],align='center',height=2*h,linewidth=0,edgecolor='tab:purple',color='tab:purple')
bh6 = ax2.barh(bar_y[0],PE_Bk[5],align='center',height=2*h,linewidth=0,edgecolor='tab:brown',color='tab:brown')
ax2.bar_label(bh1,fmt='%.3f',padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh2,fmt='%.3f',padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh3,fmt='%.3f',padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh4,fmt='%.3f',padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh5,fmt='%.3f',padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh6,fmt='%.3f',padding=6,fontsize=14,weight='normal',color='black')
ax2.set_xlabel('Element strain energy ($\\rm{\mu J}$)',fontsize=20)
# ax2.set_ylabel('Case',fontsize=20)
ax2.set_xlim(0,0.325)
ax2.set_ylim(1-w-2*g,1+11*w+7*g)
# ax2.set_xticks([0,0.05,0.1,0.15,0.2])
# ax2.set_xticklabels(['0','0.05','0.1','0.15','0.2'],fontsize=18)
ax2.set_xticks([0,0.1,0.2,0.3])
ax2.set_xticklabels(['0','0.1','0.2','0.3'],fontsize=18)
ax2.set_yticks([1,1+2*w+g,1+4*w+2*g,1+6*w+3*g,1+8*w+4*g,1+10*w+5*g])
# ax2.set_yticklabels(['M-P-C','P-M-C','C-M-P','P-C-M','C-P-M','M-C-P'],fontsize=16) # Wrong order!
ax2.set_yticklabels(['P-M-C','C-M-P','P-C-M','C-P-M','M-C-P','M-P-C'],fontsize=16)
# fig2.savefig('Figure7a2.png', dpi=1200)
# Out:
# [Text(0, 1.0, 'P-M-C'),
#  Text(0, 1.32, 'C-M-P'),
#  Text(0, 1.6400000000000001, 'P-C-M'),
#  Text(0, 1.96, 'C-P-M'),
#  Text(0, 2.2800000000000002, 'M-C-P'),
#  Text(0, 2.6, 'M-P-C')]

# %%
# Figure 7(b)
fig3,ax3 = plt.subplots(layout = 'constrained',figsize=(5,8))
ax3.plot(time[0:201],KE_Fr_s1c1[0:201],linewidth=4,color='tab:pink',label='C as the first layer')
#ax3.plot(time[0:401],KE_Fr_s3c1[0:401],linewidth=2,color='tab:orange',label='CMP, 132')
ax3.plot(time[0:201],KE_Fr_s3c2[0:201],linewidth=4,color='tab:olive',label='P as the first layer')
#ax3.plot(time[0:401],KE_Fr_s3c3[0:401],linewidth=2,color='tab:red',label='PMC, 231')
ax3.plot(time[0:201],KE_Fr_s3c4[0:201],linewidth=4,color='tab:cyan',label='M as the first layer')
#ax3.plot(time[0:401],KE_Fr_s3c5[0:401],linewidth=2,color='tab:brown',label='MPC, 321')
ax3.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=20)
ax3.set_ylabel('Element kinetic energy ($\\rm{\mu J}$)',fontsize=20)
ax3.set_xlim(0,2.1)
ax3.set_ylim(0,142)
ax3.set_xticks([0,0.5,1,1.5,2])
ax3.set_xticklabels(['0','0.5','1','1.5','2'],fontsize=18)
ax3.set_yticks([0,40,80,120])
ax3.set_yticklabels(['0','40','80','120'],fontsize=18)
legend = ax3.legend(loc='lower right',fontsize=16)
# fig3.savefig('Figure7b1.png', dpi=1200)

w = 0.3/2
g = 0.02
h = 0.6*w
bar_y = [1+10*w+5*g,1+8*w+4*g,1+6*w+3*g,1+4*w+2*g,1+2*w+g,1]
KE_Bk = [max(KE_Bk_s1c1[600:1281]),
         max(KE_Bk_s3c1[600:1456]),
         max(KE_Bk_s3c2[600:1456]),
         max(KE_Bk_s3c3[600:1456]),
         max(KE_Bk_s3c4[600:1456]),
         max(KE_Bk_s3c5[600:1371])]
fig4,ax4 = plt.subplots(layout = 'constrained',figsize=(5,8)) # 9,5.4
# ax4.yaxis.tick_right()
# ax4.yaxis.set_label_position('right')
bh1 = ax4.barh(bar_y[5],KE_Bk[0],align='center',height=2*h,linewidth=0,edgecolor='tab:blue',color='tab:blue')
bh2 = ax4.barh(bar_y[0],KE_Bk[1],align='center',height=2*h,linewidth=0,edgecolor='tab:orange',color='tab:orange')
bh3 = ax4.barh(bar_y[4],KE_Bk[2],align='center',height=2*h,linewidth=0,edgecolor='tab:green',color='tab:green')
bh4 = ax4.barh(bar_y[3],KE_Bk[3],align='center',height=2*h,linewidth=0,edgecolor='tab:red',color='tab:red')
bh5 = ax4.barh(bar_y[1],KE_Bk[4],align='center',height=2*h,linewidth=0,edgecolor='tab:purple',color='tab:purple')
bh6 = ax4.barh(bar_y[2],KE_Bk[5],align='center',height=2*h,linewidth=0,edgecolor='tab:brown',color='tab:brown')
ax4.bar_label(bh1,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh2,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh3,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh4,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh5,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh6,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax4.set_xlabel('Element kinetic energy ($\\rm{\mu J}$)',fontsize=20)
# ax4.set_ylabel('Case',fontsize=20)
ax4.set_xlim(0,54)
ax4.set_ylim(1-w-2*g,1+11*w+7*g)
ax4.set_xticks([0,15,30,45])
ax4.set_xticklabels(['0','15','30','45'],fontsize=18)
ax4.set_yticks([1,1+2*w+g,1+4*w+2*g,1+6*w+3*g,1+8*w+4*g,1+10*w+5*g])
ax4.set_yticklabels(['C-P-M','P-C-M','P-M-C','M-P-C','M-C-P','C-M-P'],fontsize=16)
# fig4.savefig('Figure7b2.png', dpi=1200)
# Out:
# [Text(0, 1.0, 'C-P-M'),
#  Text(0, 1.32, 'P-C-M'),
#  Text(0, 1.6400000000000001, 'P-M-C'),
#  Text(0, 1.96, 'M-P-C'),
#  Text(0, 2.2800000000000002, 'M-C-P'),
#  Text(0, 2.6, 'C-M-P')]
