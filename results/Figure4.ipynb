# %%
import matplotlib.pyplot as plt
import math

# ERV on Element 2
# PC/ABS @ 5 m/s; 4790/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_5/abq_run/Job-1_erv_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
erv_e2_pcabs_5 = [float(item[1]) for item in data2]

# PC/ABS @ 20 m/s; 19160/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_20/abq_run/Job-1_erv_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
erv_e2_pcabs_20 = [float(item[1]) for item in data2]

# PC/ABS @ 50 m/s; 47900/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_50/abq_run/Job-1_erv_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
erv_e2_pcabs_50 = [float(item[1]) for item in data2]

# Al-6061 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Al6061_50/abq_run/Job-1_erv_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
erv_e2_al6061_50 = [float(item[1]) for item in data2]

# Steel-4340 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Steel4340_50/abq_run/Job-1_erv_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
erv_e2_steel4340_50 = [float(item[1]) for item in data2]

# SiC @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JH2-SiC_50/abq_run/Job-1_erv_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
erv_e2_sic_50 = [float(item[1]) for item in data2]

# Figure 4(a)
fig1,ax1 = plt.subplots(layout='constrained',figsize=(9,5.4))
ax1.plot(time[0:67],erv_e2_pcabs_5[0:67],linewidth=4,color='tab:blue',label='PC/ABS, 5 m/s')
ax1.plot(time[0:67],erv_e2_pcabs_20[0:67],linewidth=4,color='tab:orange',label='PC/ABS, 20 m/s')
ax1.plot(time[0:67],erv_e2_pcabs_50[0:67],linewidth=4,color='tab:green',label='PC/ABS, 50 m/s')
ax1.plot(time[0:18],erv_e2_al6061_50[0:18],linewidth=4,color='tab:red',label='Al-6061, 50 m/s')
ax1.plot(time[0:20],erv_e2_steel4340_50[0:20],linewidth=4,color='tab:purple',label='Steel-4340, 50 m/s')
ax1.plot(time[0:13],erv_e2_sic_50[0:13],linewidth=4,color='tab:brown',label='SiC, 50 m/s')
ax1.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=19)
ax1.set_ylabel('Element volumetric strain rate ($\\rm{/s}$)',fontsize=19)
ax1.set_xlim(0,3.4)
ax1.set_ylim(-67000,0)
ax1.set_xticks([0,1,2,3])
ax1.set_xticklabels(['0','1','2','3'],fontsize=18)
ax1.set_yticks([-60000,-40000,-20000,0])
ax1.tick_params(axis='y',labelsize=18)
ax1.ticklabel_format(axis='y',style='sci',scilimits=[0,0],useMathText=True)
ax1.yaxis.offsetText.set_fontsize(18)
legend = ax1.legend(loc='upper left',bbox_to_anchor=(0.29,0.67),fontsize=20)
# fig1.savefig('Figure4a.png', dpi=1200)

# %%
# LE11 (convert to E11) on Element 2
# PC/ABS @ 5 m/s; 4790/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_5/abq_run/Job-1_le11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
le11_e2_pcabs_5 = [math.exp(float(item[1]))-1 for item in data2]

# PC/ABS @ 20 m/s; 19160/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_20/abq_run/Job-1_le11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_pcabs_20 = [math.exp(float(item[1]))-1 for item in data2]

# PC/ABS @ 50 m/s; 47900/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_50/abq_run/Job-1_le11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_pcabs_50 = [math.exp(float(item[1]))-1 for item in data2]

# Al-6061 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Al6061_50/abq_run/Job-1_le11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_al6061_50 = [math.exp(float(item[1]))-1 for item in data2]

# Steel-4340 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Steel4340_50/abq_run/Job-1_le11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_steel4340_50 = [math.exp(float(item[1]))-1 for item in data2]

# SiC @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JH2-SiC_50/abq_run/Job-1_le11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
le11_e2_sic_50 = [math.exp(float(item[1]))-1 for item in data2]

# Figure 4(b)
fig2,ax2 = plt.subplots(layout='constrained',figsize=(9,5.4))
ax2.plot(time[0:176],le11_e2_pcabs_5[0:176],linewidth=4,color='tab:blue',label='PC/ABS, 5 m/s')
ax2.plot(time[0:176],le11_e2_pcabs_20[0:176],linewidth=4,color='tab:orange',label='PC/ABS, 20 m/s')
ax2.plot(time[0:176],le11_e2_pcabs_50[0:176],linewidth=4,color='tab:green',label='PC/ABS, 50 m/s')
ax2.plot(time[0:49],le11_e2_al6061_50[0:49],linewidth=4,color='tab:red',label='Al-6061, 50 m/s')
ax2.plot(time[0:53],le11_e2_steel4340_50[0:53],linewidth=4,color='tab:purple',label='Steel-4340, 50 m/s')
ax2.plot(time[0:35],le11_e2_sic_50[0:35],linewidth=4,color='tab:brown',label='SiC, 50 m/s')
ax2.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=19)
ax2.set_ylabel('Element volumetric strain',fontsize=19)
ax2.set_xlim(0,9)
ax2.set_ylim(-0.0305,0)
ax2.set_xticks([0,2,4,6,8])
ax2.set_xticklabels(['0','2','4','6','8'],fontsize=18)
ax2.set_yticks([-0.03,-0.02,-0.01,0])
# ax2.set_yticklabels(['-0.03','-0.02','-0.01','0'],fontsize=18)
ax2.tick_params(axis='y',labelsize=18)
ax2.ticklabel_format(axis='y',style='sci',scilimits=[0,0],useMathText=True)
ax2.yaxis.offsetText.set_fontsize(18)
# legend = ax2.legend(loc='upper right',bbox_to_anchor=(0.85,0.58),fontsize=16)
# fig2.savefig('Figure4b.png', dpi=1200)

# %%
# PEEQ on Element 2
# PCABS @ 5 m/s; 4790/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_5/abq_run/Job-1_peeq_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
peeq_e2_pcabs_5 = [float(item[1]) for item in data2]

# PCABS @ 20 m/s; 19160/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_20/abq_run/Job-1_peeq_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
peeq_e2_pcabs_20 = [float(item[1]) for item in data2]

# PCABS @ 50 m/s; 47900/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_50/abq_run/Job-1_peeq_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
peeq_e2_pcabs_50 = [float(item[1]) for item in data2]

# Al6061 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Al6061_50/abq_run/Job-1_peeq_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
peeq_e2_al6061_50 = [float(item[1]) for item in data2]

# Steel4340 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Steel4340_50/abq_run/Job-1_peeq_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
peeq_e2_steel4340_50 = [float(item[1]) for item in data2]

# SiC @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JH2-SiC_50/abq_run/Job-1_peeq_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
peeq_e2_sic_50 = [float(item[1]) for item in data2]

# Figure 4(c)
fig3,ax3 = plt.subplots(layout = 'constrained',figsize=(9,5.4))
ax3.plot(time[0:176],peeq_e2_pcabs_5[0:176],linewidth=4,color='tab:blue',label='PC/ABS, 5 m/s')
ax3.plot(time[0:176],peeq_e2_pcabs_20[0:176],linewidth=4,color='tab:orange',label='PC/ABS, 20 m/s')
ax3.plot(time[0:176],peeq_e2_pcabs_50[0:176],linewidth=4,color='tab:green',label='PC/ABS, 50 m/s')
ax3.plot(time[0:176],peeq_e2_al6061_50[0:176],linewidth=4,color='tab:red',label='Al-6061, 50 m/s')
ax3.plot(time[0:176],peeq_e2_steel4340_50[0:176],linewidth=4,color='tab:purple',label='Steel-4340, 50 m/s')
ax3.plot(time[0:176],peeq_e2_sic_50[0:176],linewidth=4,color='tab:brown',label='SiC, 50 m/s')
ax3.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=19)
ax3.set_ylabel('Element equivalent plastic strain',fontsize=19)
ax3.set_xlim(0,9)
ax3.set_ylim(0,0.013)
ax3.set_xticks([0,2,4,6,8])
ax3.set_xticklabels(['0','2','4','6','8'],fontsize=18)
ax3.set_yticks([0,0.004,0.008,0.012])
# ax3.set_yticklabels(['0','0.004','0.008','0.012'],fontsize=18)
ax3.tick_params(axis='y',labelsize=18)
ax3.ticklabel_format(axis='y',style='sci',scilimits=[0,0],useMathText=True)
ax3.yaxis.offsetText.set_fontsize(18)
# legend = ax3.legend(loc='upper left',bbox_to_anchor=(0.45,0.87),fontsize=16)
# fig3.savefig('Figure4c.png', dpi=1200,bbox_inches='tight')

fig3s,ax3s= plt.subplots(layout = 'constrained',figsize=(6,5))
ax3s.plot(time[0:176],peeq_e2_pcabs_5[0:176],linewidth=8,color='tab:blue',label='PC/ABS, 5 m/s')
ax3s.plot(time[0:176],peeq_e2_pcabs_20[0:176],linewidth=8,color='tab:orange',label='PC/ABS, 20 m/s')
ax3s.plot(time[0:176],peeq_e2_pcabs_50[0:176],linewidth=8,color='tab:green',label='PC/ABS, 50 m/s')
ax3s.plot(time[0:176],peeq_e2_al6061_50[0:176],linewidth=8,color='tab:red',label='Al-6061, 50 m/s')
ax3s.plot(time[0:176],peeq_e2_steel4340_50[0:176],linewidth=8,color='tab:purple',label='Steel-4340, 50 m/s')
ax3s.plot(time[0:176],peeq_e2_sic_50[0:176],linewidth=8,color='tab:brown',label='SiC, 50 m/s')
# ax3s.set_xlabel('Time ($\mu s$)',fontsize=18)
# ax3s.set_ylabel('Element equivalent plastic strain',fontsize=18)
ax3s.set_xlim(0,4)
ax3s.set_ylim(0.000055,0.000080)
ax3s.set_xticks([0,2,4])
ax3s.set_xticklabels(['0','2','4'],fontsize=40)
ax3s.set_yticks([6.76158888382e-05])
ax3s.tick_params(axis='y',labelsize=40)
ax3s.ticklabel_format(axis='y',style='sci',useMathText=True)
ax3s.yaxis.offsetText.set_fontsize(40)
# legend = ax3s.legend(loc='lower right',fontsize=12)
# fig3s.savefig('Figure4cs.png', dpi=1200,bbox_inches='tight')

# %%
# MISES on Element 2
# PCABS @ 5 m/s; 4790/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_5/abq_run/Job-1_mises_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
mises_e2_pcabs_5 = [float(item[1]) for item in data2]

# PCABS @ 20 m/s; 19160/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_20/abq_run/Job-1_mises_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
mises_e2_pcabs_20 = [float(item[1]) for item in data2]

# PCABS @ 50 m/s; 47900/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_50/abq_run/Job-1_mises_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
mises_e2_pcabs_50 = [float(item[1]) for item in data2]

# Al6061 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Al6061_50/abq_run/Job-1_mises_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
mises_e2_al6061_50 = [float(item[1]) for item in data2]

# Steel4340 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Steel4340_50/abq_run/Job-1_mises_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
mises_e2_steel4340_50 = [float(item[1]) for item in data2]

# SiC @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JH2-SiC_50/abq_run/Job-1_mises_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
mises_e2_sic_50 = [float(item[1]) for item in data2]

# Figure 4(d)
fig4,ax4 = plt.subplots(layout = 'constrained',figsize=(9,5.4))
ax4.plot(time[0:176],mises_e2_pcabs_5[0:176],linewidth=4,color='tab:blue',label='PC/ABS, 5 m/s')
ax4.plot(time[0:176],mises_e2_pcabs_20[0:176],linewidth=4,color='tab:orange',label='PC/ABS, 20 m/s')
ax4.plot(time[0:176],mises_e2_pcabs_50[0:176],linewidth=4,color='tab:green',label='PC/ABS, 50 m/s')
ax4.plot(time[0:49],mises_e2_al6061_50[0:49],linewidth=4,color='tab:red',label='Al-6061, 50 m/s')
ax4.plot(time[0:53],mises_e2_steel4340_50[0:53],linewidth=4,color='tab:purple',label='Steel-4340, 50 m/s')
ax4.plot(time[0:33],mises_e2_sic_50[0:33],linewidth=4,color='tab:brown',label='SiC, 50 m/s')
ax4.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=19)
ax4.set_ylabel('Element von Mises stress (MPa)',fontsize=19)
ax4.set_xlim(0,9)
ax4.set_ylim(0,1300)
ax4.set_xticks([0,2,4,6,8])
ax4.set_xticklabels(['0','2','4','6','8'],fontsize=18)
# ax4.set_yticks([0,5,10,15,20,25])
# ax4.set_yticklabels(['0','5','10','15','20','25'],fontsize=18)
ax4.tick_params(axis='y',labelsize=18)
ax4.ticklabel_format(axis='y',style='sci',scilimits=[0,0],useMathText=True)
ax4.yaxis.offsetText.set_fontsize(18)
# legend = ax4.legend(loc='upper left',bbox_to_anchor=(0.18,0.99),fontsize=16)
fig4.savefig('Figure4d.png', dpi=1200)

fig4s,ax4s = plt.subplots(layout = 'constrained',figsize=(8,5.4))
ax4s.plot(time[0:176],mises_e2_pcabs_5[0:176],linewidth=6,color='tab:blue',label='PC/ABS, 5 m/s')
ax4s.plot(time[0:176],mises_e2_pcabs_20[0:176],linewidth=6,color='tab:orange',label='PC/ABS, 20 m/s')
ax4s.plot(time[0:176],mises_e2_pcabs_50[0:176],linewidth=6,color='tab:green',label='PC/ABS, 50 m/s')
# ax4s.set_xlabel('Time ($\mu s$)',fontsize=19)
# ax4s.set_ylabel('Element von Mises stress (MPa)',fontsize=19)
ax4s.set_xlim(2,9)
ax4s.set_ylim(0,29)
ax4s.set_xticks([2,4,6,8])
ax4s.set_xticklabels(['2','4','6','8'],fontsize=28)
ax4s.set_yticks([5,15,25])
ax4s.set_yticklabels(['5','15','25'],fontsize=28)
# legend = ax4s.legend(loc='upper left',bbox_to_anchor=(0.18,0.99),fontsize=16)
# fig4s.savefig('Figure4ds.png', dpi=1200)
# Out:
# [Text(0, 5, '5'), Text(0, 15, '15'), Text(0, 25, '25')]
