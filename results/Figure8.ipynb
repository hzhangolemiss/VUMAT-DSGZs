# %%
import matplotlib.pyplot as plt

# Mid-plane velocity for Bone (no gap)
# 1. stage 6; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage6-case1-sq123_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
v1_n2_Bo_s6c1 = [0.001*float(item[1]) for item in data2]

# 2. stage 6; case 2; CMP == 132
with open('../2_CPM_Comp_Impact/stage6-case2-sq132_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s6c2 = [0.001*float(item[1]) for item in data2]

# 3. stage 6; case 3; PCM == 213
with open('../2_CPM_Comp_Impact/stage6-case3-sq213_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s6c3 = [0.001*float(item[1]) for item in data2]

# 4. stage 6; case 4; PMC == 231
with open('../2_CPM_Comp_Impact/stage6-case4-sq231_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s6c4 = [0.001*float(item[1]) for item in data2]

# 5. stage 6; case 5; MCP == 312
with open('../2_CPM_Comp_Impact/stage6-case5-sq312_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s6c5 = [0.001*float(item[1]) for item in data2]

# 6. stage 6; case 6; MPC == 321
with open('../2_CPM_Comp_Impact/stage6-case6-sq321_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s6c6 = [0.001*float(item[1]) for item in data2]

# 7. stage 6; case 7; C == 1
with open('../2_CPM_Comp_Impact/stage6-case7-C_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s6c7 = [0.001*float(item[1]) for item in data2]
# 8. stage 6; case 8; P == 2
with open('../2_CPM_Comp_Impact/stage6-case8-P_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s6c8 = [0.001*float(item[1]) for item in data2]
# 9. stage 6; case 9; M == 3
with open('../2_CPM_Comp_Impact/stage6-case9-M_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s6c9 = [0.001*float(item[1]) for item in data2]

# Mid-plane stress for Bone (no gap)
# 1. stage 6; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage6-case1-sq123_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
s11_e2_Bo_s6c1 = [float(item[1]) for item in data2]

# 2. stage 6; case 2; CMP == 132
with open('../2_CPM_Comp_Impact/stage6-case2-sq132_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s6c2 = [float(item[1]) for item in data2]

# 3. stage 6; case 3; PCM == 213
with open('../2_CPM_Comp_Impact/stage6-case3-sq213_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s6c3 = [float(item[1]) for item in data2]

# 4. stage 6; case 4; PMC == 231
with open('../2_CPM_Comp_Impact/stage6-case4-sq231_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s6c4 = [float(item[1]) for item in data2]

# 5. stage 6; case 5; MCP == 312
with open('../2_CPM_Comp_Impact/stage6-case5-sq312_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s6c5 = [float(item[1]) for item in data2]

# 6. stage 6; case 6; MPC == 321
with open('../2_CPM_Comp_Impact/stage6-case6-sq321_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s6c6 = [float(item[1]) for item in data2]

# 7. stage 6; case 7; C == 1
with open('../2_CPM_Comp_Impact/stage6-case7-C_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s6c7 = [float(item[1]) for item in data2]
# 8. stage 6; case 8; P == 2
with open('../2_CPM_Comp_Impact/stage6-case8-P_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s6c8 = [float(item[1]) for item in data2]
# 9. stage 6; case 9; M == 3
with open('../2_CPM_Comp_Impact/stage6-case9-M_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s6c9 = [float(item[1]) for item in data2]

# %%
# Figure 8
fig1,ax1 = plt.subplots(layout = 'constrained',figsize=(9,6.5)) # 9,5.4
ax1.plot(time[250:1160],v1_n2_Bo_s6c1[250:1160],linewidth=4,color='tab:blue',zorder=1,label='  C-P-M')
ax1.plot(time[250:1240],v1_n2_Bo_s6c2[250:1240],linewidth=4,color='tab:orange',zorder=3,label='  C-M-P')
ax1.plot(time[250:1210],v1_n2_Bo_s6c3[250:1210],linewidth=4,color='tab:green',zorder=5,label='  P-C-M')
ax1.plot(time[250:1210],v1_n2_Bo_s6c4[250:1210],linewidth=4,color='tab:red',zorder=7,label='  P-M-C')
ax1.plot(time[250:1210],v1_n2_Bo_s6c5[250:1210],linewidth=4,color='tab:purple',zorder=9,label='  M-C-P')
ax1.plot(time[250:1170],v1_n2_Bo_s6c6[250:1170],linewidth=4,color='tab:brown',zorder=11,label='  M-P-C')
ax1.plot(time[250:650],v1_n2_Bo_s6c7[250:650],linewidth=2.5,linestyle='--',color='tab:pink',zorder=13,label='  pure C')
ax1.plot(time[250:1630],v1_n2_Bo_s6c8[250:1630],linewidth=2.5,linestyle='--',color='tab:gray',zorder=15,label='  pure P')
ax1.plot(time[250:745],v1_n2_Bo_s6c9[250:745],linewidth=2.5,linestyle='--',color='tab:olive',zorder=17,label='  pure M')
ax1.scatter(time[1042],v1_n2_Bo_s6c1[1042],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:blue',zorder=2,label='{0:.1f}'.format(v1_n2_Bo_s6c1[1042]))
ax1.scatter(time[1169],v1_n2_Bo_s6c2[1169],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:orange',zorder=4,label='{0:.1f}'.format(v1_n2_Bo_s6c2[1169]))
ax1.scatter(time[1125],v1_n2_Bo_s6c3[1125],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:green',zorder=6,label='{0:.1f}'.format(v1_n2_Bo_s6c3[1125]))
ax1.scatter(time[1144],v1_n2_Bo_s6c4[1144],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:red',zorder=8,label='{0:.1f}'.format(v1_n2_Bo_s6c4[1144]))
ax1.scatter(time[1134],v1_n2_Bo_s6c5[1134],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:purple',zorder=10,label='{0:.1f}'.format(v1_n2_Bo_s6c5[1134]))
ax1.scatter(time[1081],v1_n2_Bo_s6c6[1081],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:brown',zorder=12,label='{0:.1f}'.format(v1_n2_Bo_s6c6[1081]))
ax1.scatter(time[606],v1_n2_Bo_s6c7[606],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:pink',zorder=14,label='{0:.1f}'.format(v1_n2_Bo_s6c7[606]))
ax1.scatter(time[1554],v1_n2_Bo_s6c8[1554],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:gray',zorder=16,label='{0:.1f}'.format(v1_n2_Bo_s6c8[1554]))
ax1.scatter(time[695],v1_n2_Bo_s6c9[695],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:olive',zorder=18,label='{0:.1f}'.format(v1_n2_Bo_s6c9[695]))
ax1.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=20)
ax1.set_ylabel('Mid-plane velocity $v_{xx}$ (m/s)',fontsize=20)
ax1.set_xlim(3.5,16.5)
ax1.set_ylim(0,105)
ax1.set_xticks([4,6,8,10,12,14,16])
ax1.set_xticklabels(['4','6','8','10','12','14','16'],fontsize=18)
ax1.set_yticks([0,20,40,60,80,100])
ax1.set_yticklabels(['0','20','40','60','80','100'],fontsize=18)
legend = ax1.legend(ncols=2,handletextpad=-0.2,columnspacing=0,loc='upper right',fontsize=14)
# legend = ax1.legend(loc='upper right',fontsize=14,
#                     labelcolor=['tab:blue','tab:orange','tab:green','tab:red','tab:purple','tab:brown',
#                                 'tab:pink','tab:gray','tab:olive'])
# fig1.savefig('Figure8a.png', dpi=1200)

bar_y = [9,8,7,6,5,4,3,2,1]
s11_e2_Bo = [s11_e2_Bo_s6c1[1042],
             s11_e2_Bo_s6c2[1169],
             s11_e2_Bo_s6c3[1125],
             s11_e2_Bo_s6c4[1144],
             s11_e2_Bo_s6c5[1134],
             s11_e2_Bo_s6c6[1081],
             s11_e2_Bo_s6c7[606],
             s11_e2_Bo_s6c8[1554],
             s11_e2_Bo_s6c9[695]]
fig2,ax2 = plt.subplots(layout = 'constrained',figsize=(6,6.5)) # 9,5.4
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position('right')
bh1 = ax2.barh(bar_y[7],s11_e2_Bo[0],align='center',height=0.45,linewidth=2,edgecolor='tab:blue',color='tab:blue')
bh2 = ax2.barh(bar_y[3],s11_e2_Bo[1],align='center',height=0.45,linewidth=2,edgecolor='tab:orange',color='tab:orange')
bh3 = ax2.barh(bar_y[8],s11_e2_Bo[2],align='center',height=0.45,linewidth=2,edgecolor='tab:green',color='tab:green')
bh4 = ax2.barh(bar_y[6],s11_e2_Bo[3],align='center',height=0.45,linewidth=2,edgecolor='tab:red',color='tab:red')
bh5 = ax2.barh(bar_y[2],s11_e2_Bo[4],align='center',height=0.45,linewidth=2,edgecolor='tab:purple',color='tab:purple')
bh6 = ax2.barh(bar_y[4],s11_e2_Bo[5],align='center',height=0.45,linewidth=2,edgecolor='tab:brown',color='tab:brown')
bh7 = ax2.barh(bar_y[1],s11_e2_Bo[6],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:pink',color='tab:pink')
bh8 = ax2.barh(bar_y[5],s11_e2_Bo[7],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:gray',color='tab:gray')
bh9 = ax2.barh(bar_y[0],s11_e2_Bo[8],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:olive',color='tab:olive')
# ax2.bar_label(bh1,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh2,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh3,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh4,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh5,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh6,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh7,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh8,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh9,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh1,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[0]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh2,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[1]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh3,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[2]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh4,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[3]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh5,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[4]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh6,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[5]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh7,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[6]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh8,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[7]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh9,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[8]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.set_xlabel('Mid-plane stress $\sigma_{xx}$ (MPa) @ $v_{xx}^{max}$',fontsize=20)
# ax2.set_ylabel('Case',fontsize=20)
ax2.set_xlim(-518,0)
ax2.set_ylim(0,10)
ax2.set_xticks([-400,-300,-200,-100,0])
ax2.set_xticklabels(['\N{MINUS SIGN}400','\N{MINUS SIGN}300','\N{MINUS SIGN}200','\N{MINUS SIGN}100','0'],fontsize=18)
ax2.set_yticks([1,2,3,4,5,6,7,8,9])
# ax2.set_yticklabels(['pure M','pure P','pure C','M-P-C','M-C-P','P-M-C','P-C-M','C-M-P','C-P-M'],fontsize=14)
ax2.set_yticklabels(['P-C-M','C-P-M','P-M-C','pure P','M-P-C','C-M-P','M-C-P','pure C','pure M'],fontsize=14)
# fig2.savefig('Figure8b.png', dpi=1200)
