# %%
import matplotlib.pyplot as plt

# Mid-plane velocity for Bone @ 1.0 mm gap
# 1. stage 7; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage7-case1-sq123_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
v1_n2_Bo_s7c1 = [0.001*float(item[1]) for item in data2]

# 2. stage 7; case 2; CMP == 132
with open('../2_CPM_Comp_Impact/stage7-case2-sq132_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s7c2 = [0.001*float(item[1]) for item in data2]

# 3. stage 7; case 3; PCM == 213
with open('../2_CPM_Comp_Impact/stage7-case3-sq213_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s7c3 = [0.001*float(item[1]) for item in data2]

# 4. stage 7; case 4; PMC == 231
with open('../2_CPM_Comp_Impact/stage7-case4-sq231_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s7c4 = [0.001*float(item[1]) for item in data2]

# 5. stage 7; case 5; MCP == 312
with open('../2_CPM_Comp_Impact/stage7-case5-sq312_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s7c5 = [0.001*float(item[1]) for item in data2]

# 6. stage 7; case 6; MPC == 321
with open('../2_CPM_Comp_Impact/stage7-case6-sq321_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s7c6 = [0.001*float(item[1]) for item in data2]

# 7. stage 7; case 7; C == 1
with open('../2_CPM_Comp_Impact/stage7-case7-C_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s7c7 = [0.001*float(item[1]) for item in data2]
# 8. stage 7; case 8; P == 2
with open('../2_CPM_Comp_Impact/stage7-case8-P_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s7c8 = [0.001*float(item[1]) for item in data2]
# 9. stage 7; case 9; M == 3
with open('../2_CPM_Comp_Impact/stage7-case9-M_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s7c9 = [0.001*float(item[1]) for item in data2]

# Mid-plane stress for Bone  @ 1.0 mm gap
# 1. stage 7; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage7-case1-sq123_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
s11_e2_Bo_s7c1 = [float(item[1]) for item in data2]

# 2. stage 7; case 2; CMP == 132
with open('../2_CPM_Comp_Impact/stage7-case2-sq132_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s7c2 = [float(item[1]) for item in data2]

# 3. stage 7; case 3; PCM == 213
with open('../2_CPM_Comp_Impact/stage7-case3-sq213_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s7c3 = [float(item[1]) for item in data2]

# 4. stage 7; case 4; PMC == 231
with open('../2_CPM_Comp_Impact/stage7-case4-sq231_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s7c4 = [float(item[1]) for item in data2]

# 5. stage 7; case 5; MCP == 312
with open('../2_CPM_Comp_Impact/stage7-case5-sq312_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s7c5 = [float(item[1]) for item in data2]

# 6. stage 7; case 6; MPC == 321
with open('../2_CPM_Comp_Impact/stage7-case6-sq321_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s7c6 = [float(item[1]) for item in data2]

# 7. stage 7; case 7; C == 1
with open('../2_CPM_Comp_Impact/stage7-case7-C_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s7c7 = [float(item[1]) for item in data2]
# 8. stage 7; case 8; P == 2
with open('../2_CPM_Comp_Impact/stage7-case8-P_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s7c8 = [float(item[1]) for item in data2]
# 9. stage 7; case 9; M == 3
with open('../2_CPM_Comp_Impact/stage7-case9-M_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s7c9 = [float(item[1]) for item in data2]

# Mid-plane velocity for Bone @ 2.0 mm gap
# 1. stage 4; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage4-case1-sq123_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
v1_n2_Bo_s4c1 = [0.001*float(item[1]) for item in data2]

# 2. stage 4; case 2; CMP == 132
with open('../2_CPM_Comp_Impact/stage4-case2-sq132_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s4c2 = [0.001*float(item[1]) for item in data2]

# 3. stage 4; case 3; PCM == 213
with open('../2_CPM_Comp_Impact/stage4-case3-sq213_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s4c3 = [0.001*float(item[1]) for item in data2]

# 4. stage 4; case 4; PMC == 231
with open('../2_CPM_Comp_Impact/stage4-case4-sq231_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s4c4 = [0.001*float(item[1]) for item in data2]

# 5. stage 4; case 5; MCP == 312
with open('../2_CPM_Comp_Impact/stage4-case5-sq312_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s4c5 = [0.001*float(item[1]) for item in data2]

# 6. stage 4; case 6; MPC == 321
with open('../2_CPM_Comp_Impact/stage4-case6-sq321_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s4c6 = [0.001*float(item[1]) for item in data2]

# 7. stage 5; case 4; C == 1
with open('../2_CPM_Comp_Impact/stage5-case4-C_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s5c4 = [0.001*float(item[1]) for item in data2]
# 8. stage 5; case 5; P == 2
with open('../2_CPM_Comp_Impact/stage5-case5-P_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s5c5 = [0.001*float(item[1]) for item in data2]
# 9. stage 5; case 6; M == 3
with open('../2_CPM_Comp_Impact/stage5-case6-M_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s5c6 = [0.001*float(item[1]) for item in data2]

# Mid-plane stress for Bone  @ 2.0 mm gap
# 1. stage 4; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage4-case1-sq123_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
s11_e2_Bo_s4c1 = [float(item[1]) for item in data2]

# 2. stage 4; case 2; CMP == 132
with open('../2_CPM_Comp_Impact/stage4-case2-sq132_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s4c2 = [float(item[1]) for item in data2]

# 3. stage 4; case 3; PCM == 213
with open('../2_CPM_Comp_Impact/stage4-case3-sq213_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s4c3 = [float(item[1]) for item in data2]

# 4. stage 4; case 4; PMC == 231
with open('../2_CPM_Comp_Impact/stage4-case4-sq231_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s4c4 = [float(item[1]) for item in data2]

# 5. stage 4; case 5; MCP == 312
with open('../2_CPM_Comp_Impact/stage4-case5-sq312_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s4c5 = [float(item[1]) for item in data2]

# 6. stage 4; case 6; MPC == 321
with open('../2_CPM_Comp_Impact/stage4-case6-sq321_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s4c6 = [float(item[1]) for item in data2]

# 7. stage 5; case 4; C == 1
with open('../2_CPM_Comp_Impact/stage5-case4-C_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s5c4 = [float(item[1]) for item in data2]
# 8. stage 5; case 5; P == 2
with open('../2_CPM_Comp_Impact/stage5-case5-P_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s5c5 = [float(item[1]) for item in data2]
# 9. stage 5; case 6; M == 3
with open('../2_CPM_Comp_Impact/stage5-case6-M_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s5c6 = [float(item[1]) for item in data2]

# Mid-plane velocity for Bone @ 3.0 mm gap
# 1. stage 8; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage8-case1-sq123_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
v1_n2_Bo_s8c1 = [0.001*float(item[1]) for item in data2]

# 2. stage 8; case 2; CMP == 132
with open('../2_CPM_Comp_Impact/stage8-case2-sq132_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s8c2 = [0.001*float(item[1]) for item in data2]

# 3. stage 8; case 3; PCM == 213
with open('../2_CPM_Comp_Impact/stage8-case3-sq213_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s8c3 = [0.001*float(item[1]) for item in data2]

# 4. stage 8; case 4; PMC == 231
with open('../2_CPM_Comp_Impact/stage8-case4-sq231_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s8c4 = [0.001*float(item[1]) for item in data2]

# 5. stage 8; case 5; MCP == 312
with open('../2_CPM_Comp_Impact/stage8-case5-sq312_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time1 = [1000000*float(item[0]) for item in data2]
v1_n2_Bo_s8c5 = [0.001*float(item[1]) for item in data2]

# 6. stage 8; case 6; MPC == 321
with open('../2_CPM_Comp_Impact/stage8-case6-sq321_s2_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s8c6 = [0.001*float(item[1]) for item in data2]

# 7. stage 8; case 7; C == 1
with open('../2_CPM_Comp_Impact/stage8-case7-C_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s8c7 = [0.001*float(item[1]) for item in data2]
# 8. stage 8; case 8; P == 2
with open('../2_CPM_Comp_Impact/stage8-case8-P_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s8c8 = [0.001*float(item[1]) for item in data2]
# 9. stage 8; case 9; M == 3
with open('../2_CPM_Comp_Impact/stage8-case9-M_50/abq_run/Job-1_v1_n2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n2_Bo_s8c9 = [0.001*float(item[1]) for item in data2]

# Mid-plane stress for Bone  @ 3.0 mm gap
# 1. stage 8; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage8-case1-sq123_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
s11_e2_Bo_s8c1 = [float(item[1]) for item in data2]

# 2. stage 8; case 2; CMP == 132
with open('../2_CPM_Comp_Impact/stage8-case2-sq132_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s8c2 = [float(item[1]) for item in data2]

# 3. stage 8; case 3; PCM == 213
with open('../2_CPM_Comp_Impact/stage8-case3-sq213_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s8c3 = [float(item[1]) for item in data2]

# 4. stage 8; case 4; PMC == 231
with open('../2_CPM_Comp_Impact/stage8-case4-sq231_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s8c4 = [float(item[1]) for item in data2]

# 5. stage 8; case 5; MCP == 312
with open('../2_CPM_Comp_Impact/stage8-case5-sq312_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time1 = [1000000*float(item[0]) for item in data2]
s11_e2_Bo_s8c5 = [float(item[1]) for item in data2]

# 6. stage 8; case 6; MPC == 321
with open('../2_CPM_Comp_Impact/stage8-case6-sq321_s2_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s8c6 = [float(item[1]) for item in data2]

# 7. stage 8; case 7; C == 1
with open('../2_CPM_Comp_Impact/stage8-case7-C_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s8c7 = [float(item[1]) for item in data2]
# 8. stage 8; case 8; P == 2
with open('../2_CPM_Comp_Impact/stage8-case8-P_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s8c8 = [float(item[1]) for item in data2]
# 9. stage 8; case 9; M == 3
with open('../2_CPM_Comp_Impact/stage8-case9-M_50/abq_run/Job-1_s11_e2_Bo.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
s11_e2_Bo_s8c9 = [float(item[1]) for item in data2]

# %%
# Figure 9(a)
fig1,ax1 = plt.subplots(layout = 'constrained',figsize=(9,6.5)) # 9,5.4
ax1.plot(time[2000:2485],v1_n2_Bo_s7c1[2000:2485],linewidth=4,color='tab:blue',zorder=1)
ax1.plot(time[2000:2190],v1_n2_Bo_s7c2[2000:2190],linewidth=4,color='tab:orange',zorder=3)
ax1.plot(time[2000:2670],v1_n2_Bo_s7c3[2000:2670],linewidth=4,color='tab:green',zorder=5)
ax1.plot(time[2000:2675],v1_n2_Bo_s7c4[2000:2675],linewidth=4,color='tab:red',zorder=7)
ax1.plot(time[2000:2185],v1_n2_Bo_s7c5[2000:2185],linewidth=4,color='tab:purple',zorder=9)
ax1.plot(time[2000:2304],v1_n2_Bo_s7c6[2000:2304],linewidth=4,color='tab:brown',zorder=11)
ax1.plot(time[2000:2375],v1_n2_Bo_s7c7[2000:2375],linewidth=2.5,linestyle='--',color='tab:pink',zorder=13)
ax1.plot(time[2000:2640],v1_n2_Bo_s7c8[2000:2640],linewidth=2.5,linestyle='--',color='tab:gray',zorder=15)
ax1.plot(time[2000:2385],v1_n2_Bo_s7c9[2000:2385],linewidth=2.5,linestyle='--',color='tab:olive',zorder=17)
ax1.scatter(time[2436],v1_n2_Bo_s7c1[2436],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:blue',zorder=2,label='{0:.1f}'.format(v1_n2_Bo_s7c1[2436]))
ax1.scatter(time[2109],v1_n2_Bo_s7c2[2109],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:orange',zorder=4,label='{0:.1f}'.format(v1_n2_Bo_s7c2[2109]))
ax1.scatter(time[2624],v1_n2_Bo_s7c3[2624],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:green',zorder=6,label='{0:.1f}'.format(v1_n2_Bo_s7c3[2624]))
ax1.scatter(time[2628],v1_n2_Bo_s7c4[2628],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:red',zorder=8,label='{0:.1f}'.format(v1_n2_Bo_s7c4[2628]))
ax1.scatter(time[2138],v1_n2_Bo_s7c5[2138],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:purple',zorder=10,label='{0:.1f}'.format(v1_n2_Bo_s7c5[2138]))
ax1.scatter(time[2258],v1_n2_Bo_s7c6[2258],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:brown',zorder=12,label='{0:.1f}'.format(v1_n2_Bo_s7c6[2258]))
ax1.scatter(time[2325],v1_n2_Bo_s7c7[2325],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:pink',zorder=14,label='{0:.1f}'.format(v1_n2_Bo_s7c7[2325]))
ax1.scatter(time[2588],v1_n2_Bo_s7c8[2588],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:gray',zorder=16,label='{0:.1f}'.format(v1_n2_Bo_s7c8[2588]))
ax1.scatter(time[2333],v1_n2_Bo_s7c9[2333],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:olive',zorder=18,label='{0:.1f}'.format(v1_n2_Bo_s7c9[2333]))
ax1.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=20)
ax1.set_ylabel('Mid-plane velocity $v_{xx}$ (m/s)',fontsize=20)
ax1.set_xlim(20.3,26.9)
ax1.set_ylim(0,137)
ax1.set_xticks([21,22,23,24,25,26])
ax1.set_xticklabels(['21','22','23','24','25','26'],fontsize=18)
ax1.set_yticks([0,20,40,60,80,100,120])
ax1.set_yticklabels(['0','20','40','60','80','100','120'],fontsize=18)
legend = ax1.legend(ncols=3,handletextpad=-0.2,columnspacing=0,bbox_to_anchor=(1.0,1.0),loc='upper right',fontsize=14)
# fig1.savefig('Figure9a1.png', dpi=1200)

bar_y = [9,8,7,6,5,4,3,2,1]
s11_e2_Bo = [s11_e2_Bo_s7c1[2436],
             s11_e2_Bo_s7c2[2109],
             s11_e2_Bo_s7c3[2624],
             s11_e2_Bo_s7c4[2628],
             s11_e2_Bo_s7c5[2138],
             s11_e2_Bo_s7c6[2258],
             s11_e2_Bo_s7c7[2325],
             s11_e2_Bo_s7c8[2588],
             s11_e2_Bo_s7c9[2333]]
fig2,ax2 = plt.subplots(layout = 'constrained',figsize=(6,6.5)) # 9,5.4
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position('right')
bh1 = ax2.barh(bar_y[7],s11_e2_Bo[0],align='center',height=0.45,linewidth=2,edgecolor='tab:blue',color='tab:blue')
bh2 = ax2.barh(bar_y[1],s11_e2_Bo[1],align='center',height=0.45,linewidth=2,edgecolor='tab:orange',color='tab:orange')
bh3 = ax2.barh(bar_y[8],s11_e2_Bo[2],align='center',height=0.45,linewidth=2,edgecolor='tab:green',color='tab:green')
bh4 = ax2.barh(bar_y[3],s11_e2_Bo[3],align='center',height=0.45,linewidth=2,edgecolor='tab:red',color='tab:red')
bh5 = ax2.barh(bar_y[4],s11_e2_Bo[4],align='center',height=0.45,linewidth=2,edgecolor='tab:purple',color='tab:purple')
bh6 = ax2.barh(bar_y[5],s11_e2_Bo[5],align='center',height=0.45,linewidth=2,edgecolor='tab:brown',color='tab:brown')
bh7 = ax2.barh(bar_y[0],s11_e2_Bo[6],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:pink',color='tab:pink')
bh8 = ax2.barh(bar_y[2],s11_e2_Bo[7],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:gray',color='tab:gray')
bh9 = ax2.barh(bar_y[6],s11_e2_Bo[8],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:olive',color='tab:olive')
# ax2.bar_label(bh1,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh2,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh3,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh4,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh5,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh6,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh7,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh8,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax2.bar_label(bh9,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh1,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[0]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh2,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[1]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh3,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[2]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh4,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[3]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh5,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[4]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh6,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[5]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh7,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[6]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh8,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[7]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.bar_label(bh9,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[8]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax2.set_xlabel('Mid-plane stress $\sigma_{xx}$ (MPa) @ $v_{xx}^{max}$',fontsize=20)
# ax2.set_ylabel('Case',fontsize=20)
ax2.set_xlim(-518,0)
ax2.set_ylim(0,10)
ax2.set_xticks([-400,-300,-200,-100,0])
ax2.set_xticklabels(['\N{MINUS SIGN}400','\N{MINUS SIGN}300','\N{MINUS SIGN}200','\N{MINUS SIGN}100','0'],fontsize=18)
ax2.set_yticks([1,2,3,4,5,6,7,8,9])
ax2.set_yticklabels(['P-C-M','C-P-M','pure M','M-P-C','M-C-P','P-M-C','pure P','C-M-P','pure C'],fontsize=14)
# fig2.savefig('Figure9a2.png', dpi=1200)

# %%
# Find the time (array index) of the maximum velocity, and also apply to stress; for ABOVE
print(v1_n2_Bo_s7c1[0:2485].index(max(v1_n2_Bo_s7c1[0:2485])),'v =',max(v1_n2_Bo_s7c1[2000:2485]),'s =',s11_e2_Bo_s7c1[2436])
print(v1_n2_Bo_s7c2[0:2190].index(max(v1_n2_Bo_s7c2[0:2190])),'v =',max(v1_n2_Bo_s7c2[2000:2190]),'s =',s11_e2_Bo_s7c2[2109])
print(v1_n2_Bo_s7c3[0:2740].index(max(v1_n2_Bo_s7c3[0:2740])),'v =',max(v1_n2_Bo_s7c3[2000:2740]),'s =',s11_e2_Bo_s7c3[2624])
print(v1_n2_Bo_s7c4[0:2730].index(max(v1_n2_Bo_s7c4[0:2730])),'v =',max(v1_n2_Bo_s7c4[2000:2730]),'s =',s11_e2_Bo_s7c4[2628])
print(v1_n2_Bo_s7c5[0:2185].index(max(v1_n2_Bo_s7c5[0:2185])),'v =',max(v1_n2_Bo_s7c5[2000:2185]),'s =',s11_e2_Bo_s7c5[2138])
print(v1_n2_Bo_s7c6[0:2304].index(max(v1_n2_Bo_s7c6[0:2304])),'v =',max(v1_n2_Bo_s7c6[2000:2304]),'s =',s11_e2_Bo_s7c6[2258])
print(v1_n2_Bo_s7c7[0:2375].index(max(v1_n2_Bo_s7c7[0:2375])),'v =',max(v1_n2_Bo_s7c7[2000:2375]),'s =',s11_e2_Bo_s7c7[2325])
print(v1_n2_Bo_s7c8[0:2680].index(max(v1_n2_Bo_s7c8[0:2680])),'v =',max(v1_n2_Bo_s7c8[2000:2680]),'s =',s11_e2_Bo_s7c8[2588])
print(v1_n2_Bo_s7c9[0:2385].index(max(v1_n2_Bo_s7c9[0:2385])),'v =',max(v1_n2_Bo_s7c9[2000:2385]),'s =',s11_e2_Bo_s7c9[2333])
# Out:
# 2436 v = 82.15496875 s = -283.053741455
# 2109 v = 124.012460938 s = -427.960693359
# 2624 v = 80.5156484375 s = -275.349395752
# 2628 v = 98.9251875 s = -342.057739258
# 2138 v = 93.56746875 s = -320.051727295
# 2258 v = 89.8895703125 s = -309.732971191
# 2325 v = 124.213992188 s = -428.181640625
# 2588 v = 103.716773438 s = -358.509552002
# 2333 v = 86.88175 s = -297.874542236

# %%
# Figure 9(b)
fig3,ax3 = plt.subplots(layout = 'constrained',figsize=(9,6.5)) # 9,5.4
ax3.plot(time[3500:4680],v1_n2_Bo_s4c1[3500:4680],linewidth=4,color='tab:blue',zorder=1)
ax3.plot(time[3500:4685],v1_n2_Bo_s4c2[3500:4685],linewidth=4,color='tab:orange',zorder=3)
ax3.plot(time[3500:4320],v1_n2_Bo_s4c3[3500:4320],linewidth=4,color='tab:green',zorder=5)
ax3.plot(time[3500:4330],v1_n2_Bo_s4c4[3500:4330],linewidth=4,color='tab:red',zorder=7)
ax3.plot(time[3500:4840],v1_n2_Bo_s4c5[3500:4840],linewidth=4,color='tab:purple',zorder=9)
ax3.plot(time[3500:5060],v1_n2_Bo_s4c6[3500:5060],linewidth=4,color='tab:brown',zorder=11)
ax3.plot(time[3500:4240],v1_n2_Bo_s5c4[3500:4240],linewidth=2.5,linestyle='--',color='tab:pink',zorder=13)
ax3.plot(time[3500:3750],v1_n2_Bo_s5c5[3500:3750],linewidth=2.5,linestyle='--',color='tab:gray',zorder=15)
ax3.plot(time[3500:4250],v1_n2_Bo_s5c6[3500:4250],linewidth=2.5,linestyle='--',color='tab:olive',zorder=17)
ax3.scatter(time[4550],v1_n2_Bo_s4c1[4550],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:blue',zorder=2,label='{0:.1f}'.format(v1_n2_Bo_s4c1[4550]))
ax3.scatter(time[4576],v1_n2_Bo_s4c2[4576],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:orange',zorder=4,label='{0:.1f}'.format(v1_n2_Bo_s4c2[4576]))
ax3.scatter(time[4210],v1_n2_Bo_s4c3[4210],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:green',zorder=6,label='{0:.1f}'.format(v1_n2_Bo_s4c3[4210]))
ax3.scatter(time[4231],v1_n2_Bo_s4c4[4231],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:red',zorder=8,label='{0:.1f}'.format(v1_n2_Bo_s4c4[4231]))
ax3.scatter(time[4730],v1_n2_Bo_s4c5[4730],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:purple',zorder=10,label='{0:.1f}'.format(v1_n2_Bo_s4c5[4730]))
ax3.scatter(time[4958],v1_n2_Bo_s4c6[4958],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:brown',zorder=12,label='{0:.1f}'.format(v1_n2_Bo_s4c6[4958]))
ax3.scatter(time[4182],v1_n2_Bo_s5c4[4182],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:pink',zorder=14,label='{0:.1f}'.format(v1_n2_Bo_s5c4[4182]))
ax3.scatter(time[3659],v1_n2_Bo_s5c5[3659],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:gray',zorder=16,label='{0:.1f}'.format(v1_n2_Bo_s5c5[3659]))
ax3.scatter(time[4148],v1_n2_Bo_s5c6[4148],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:olive',zorder=18,label='{0:.1f}'.format(v1_n2_Bo_s5c6[4148]))
ax3.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=20)
ax3.set_ylabel('Mid-plane velocity $v_{xx}$ (m/s)',fontsize=20)
ax3.set_xlim(35.5,51.5)
ax3.set_ylim(0,137)
ax3.set_xticks([36,38,40,42,44,46,48,50])
ax3.set_xticklabels(['36','38','40','42','44','46','48','50'],fontsize=18)
ax3.set_yticks([0,20,40,60,80,100,120])
ax3.set_yticklabels(['0','20','40','60','80','100','120'],fontsize=18)
legend = ax3.legend(ncols=3,handletextpad=-0.2,columnspacing=0,loc='upper right',bbox_to_anchor=(0.62,1.0),fontsize=14)
# fig3.savefig('Figure9b1.png', dpi=1200)

bar_y = [9,8,7,6,5,4,3,2,1]
s11_e2_Bo = [s11_e2_Bo_s4c1[4550],
             s11_e2_Bo_s4c2[4576],
             s11_e2_Bo_s4c3[4210],
             s11_e2_Bo_s4c4[4231],
             s11_e2_Bo_s4c5[4730],
             s11_e2_Bo_s4c6[4958],
             s11_e2_Bo_s5c4[4182],
             s11_e2_Bo_s5c5[3659],
             s11_e2_Bo_s5c6[4148]]
fig4,ax4 = plt.subplots(layout = 'constrained',figsize=(6,6.5)) # 9,5.4
ax4.yaxis.tick_right()
ax4.yaxis.set_label_position('right')
bh1 = ax4.barh(bar_y[6],s11_e2_Bo[0],align='center',height=0.45,linewidth=2,edgecolor='tab:blue',color='tab:blue')
bh2 = ax4.barh(bar_y[0],s11_e2_Bo[1],align='center',height=0.45,linewidth=2,edgecolor='tab:orange',color='tab:orange')
bh3 = ax4.barh(bar_y[7],s11_e2_Bo[2],align='center',height=0.45,linewidth=2,edgecolor='tab:green',color='tab:green')
bh4 = ax4.barh(bar_y[8],s11_e2_Bo[3],align='center',height=0.45,linewidth=2,edgecolor='tab:red',color='tab:red')
bh5 = ax4.barh(bar_y[2],s11_e2_Bo[4],align='center',height=0.45,linewidth=2,edgecolor='tab:purple',color='tab:purple')
bh6 = ax4.barh(bar_y[5],s11_e2_Bo[5],align='center',height=0.45,linewidth=2,edgecolor='tab:brown',color='tab:brown')
bh7 = ax4.barh(bar_y[3],s11_e2_Bo[6],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:pink',color='tab:pink')
bh8 = ax4.barh(bar_y[1],s11_e2_Bo[7],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:gray',color='tab:gray')
bh9 = ax4.barh(bar_y[4],s11_e2_Bo[8],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:olive',color='tab:olive')
# ax4.bar_label(bh1,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax4.bar_label(bh2,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax4.bar_label(bh3,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax4.bar_label(bh4,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax4.bar_label(bh5,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax4.bar_label(bh6,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax4.bar_label(bh7,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax4.bar_label(bh8,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax4.bar_label(bh9,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh1,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[0]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh2,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[1]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh3,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[2]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh4,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[3]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh5,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[4]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh6,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[5]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh7,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[6]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh8,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[7]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax4.bar_label(bh9,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[8]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax4.set_xlabel('Mid-plane stress $\sigma_{xx}$ (MPa) @ $v_{xx}^{max}$',fontsize=20)
# ax4.set_ylabel('Case',fontsize=20)
ax4.set_xlim(-518,0)
ax4.set_ylim(0,10)
ax4.set_xticks([-400,-300,-200,-100,0])
ax4.set_xticklabels(['\N{MINUS SIGN}400','\N{MINUS SIGN}300','\N{MINUS SIGN}200','\N{MINUS SIGN}100','0'],fontsize=18)
ax4.set_yticks([1,2,3,4,5,6,7,8,9])
ax4.set_yticklabels(['P-M-C','P-C-M','C-P-M','M-P-C','pure M','pure C','M-C-P','pure P','C-M-P'],fontsize=14)
# fig4.savefig('Figure9b2.png', dpi=1200)

# %%
# Find the time (array index) of the maximum velocity, and also apply to stress; for ABOVE
print(v1_n2_Bo_s4c1[0:4841].index(max(v1_n2_Bo_s4c1[0:4841])),'v =',max(v1_n2_Bo_s4c1[3500:4841]),'s =',s11_e2_Bo_s4c1[4550])
print(v1_n2_Bo_s4c2[0:4851].index(max(v1_n2_Bo_s4c2[0:4851])),'v =',max(v1_n2_Bo_s4c2[3500:4851]),'s =',s11_e2_Bo_s4c2[4576])
print(v1_n2_Bo_s4c3[0:4501].index(max(v1_n2_Bo_s4c3[0:4501])),'v =',max(v1_n2_Bo_s4c3[3500:4501]),'s =',s11_e2_Bo_s4c3[4210])
print(v1_n2_Bo_s4c4[0:4411].index(max(v1_n2_Bo_s4c4[0:4411])),'v =',max(v1_n2_Bo_s4c4[3500:4411]),'s =',s11_e2_Bo_s4c4[4231])
print(v1_n2_Bo_s4c5[0:5006].index(max(v1_n2_Bo_s4c5[0:5006])),'v =',max(v1_n2_Bo_s4c5[3500:5006]),'s =',s11_e2_Bo_s4c5[4730])
print(v1_n2_Bo_s4c6[0:5251].index(max(v1_n2_Bo_s4c6[0:5251])),'v =',max(v1_n2_Bo_s4c6[3500:5251]),'s =',s11_e2_Bo_s4c6[4958])
print(v1_n2_Bo_s5c4[0:4321].index(max(v1_n2_Bo_s5c4[0:4321])),'v =',max(v1_n2_Bo_s5c4[3500:4321]),'s =',s11_e2_Bo_s5c4[4182])
print(v1_n2_Bo_s5c5[0:3921].index(max(v1_n2_Bo_s5c5[0:3921])),'v =',max(v1_n2_Bo_s5c5[3500:3921]),'s =',s11_e2_Bo_s5c5[3659])
print(v1_n2_Bo_s5c6[0:4411].index(max(v1_n2_Bo_s5c6[0:4411])),'v =',max(v1_n2_Bo_s5c6[3500:4411]),'s =',s11_e2_Bo_s5c6[4148])
# Out:
# 4550 v = 59.9178554688 s = -205.438049316
# 4576 v = 113.28979687500001 s = -389.890319824
# 4210 v = 50.082875 s = -170.215255737
# 4231 v = 35.6761015625 s = -121.724220276
# 4730 v = 100.479851562 s = -344.236663818
# 4958 v = 74.468515625 s = -256.11227417
# 4182 v = 97.75632031250001 s = -337.237121582
# 3659 v = 108.6223125 s = -372.778869629
# 4148 v = 77.819921875 s = -268.089660645

# %%
# Figure 9(c)
fig5,ax5 = plt.subplots(layout = 'constrained',figsize=(9,6.5)) # 9,5.4
ax5.plot(time[5300:6030],v1_n2_Bo_s8c1[5300:6030],linewidth=4,color='tab:blue',zorder=1)
ax5.plot(time[5300:5636],v1_n2_Bo_s8c2[5300:5636],linewidth=4,color='tab:orange',zorder=3)
ax5.plot(time[5300:5780],v1_n2_Bo_s8c3[5300:5780],linewidth=4,color='tab:green',zorder=5)
ax5.plot(time[5300:5770],v1_n2_Bo_s8c4[5300:5770],linewidth=4,color='tab:red',zorder=7)
ax5.plot(time1[5300:7100],v1_n2_Bo_s8c5[5300:7100],linewidth=4,color='tab:purple',zorder=9)
ax5.plot(time[5300:6450],v1_n2_Bo_s8c6[5300:6450],linewidth=4,color='tab:brown',zorder=11)
ax5.plot(time[5300:6110],v1_n2_Bo_s8c7[5300:6110],linewidth=2.5,linestyle='--',color='tab:pink',zorder=13)
ax5.plot(time[5300:5540],v1_n2_Bo_s8c8[5300:5540],linewidth=2.5,linestyle='--',color='tab:gray',zorder=15)
ax5.plot(time[5300:6045],v1_n2_Bo_s8c9[5300:6045],linewidth=2.5,linestyle='--',color='tab:olive',zorder=17)
ax5.scatter(time[5948],v1_n2_Bo_s8c1[5948],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:blue',zorder=2,label='{0:.1f}'.format(v1_n2_Bo_s8c1[5948]))
ax5.scatter(time[5588],v1_n2_Bo_s8c2[5588],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:orange',zorder=4,label='{0:.1f}'.format(v1_n2_Bo_s8c2[5588]))
ax5.scatter(time[5663],v1_n2_Bo_s8c3[5663],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:green',zorder=6,label='{0:.1f}'.format(v1_n2_Bo_s8c3[5663]))
ax5.scatter(time[5684],v1_n2_Bo_s8c4[5684],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:red',zorder=8,label='{0:.1f}'.format(v1_n2_Bo_s8c4[5684]))
ax5.scatter(time1[7048],v1_n2_Bo_s8c5[7048],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:purple',zorder=10,label='{0:.1f}'.format(v1_n2_Bo_s8c5[7048]))
ax5.scatter(time[6185],v1_n2_Bo_s8c6[6185],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:brown',zorder=12,label='{0:.1f}'.format(v1_n2_Bo_s8c6[6185]))
ax5.scatter(time[6062],v1_n2_Bo_s8c7[6062],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:pink',zorder=14,label='{0:.1f}'.format(v1_n2_Bo_s8c7[6062]))
ax5.scatter(time[5442],v1_n2_Bo_s8c8[5442],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:gray',zorder=16,label='{0:.1f}'.format(v1_n2_Bo_s8c8[5442]))
ax5.scatter(time[5988],v1_n2_Bo_s8c9[5988],marker='o',linewidths=2,s=180,color='none',edgecolors='tab:olive',zorder=18,label='{0:.1f}'.format(v1_n2_Bo_s8c9[5988]))
ax5.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=20)
ax5.set_ylabel('Mid-plane velocity $v_{xx}$ (m/s)',fontsize=20)
ax5.set_xlim(53.0,71.5)
ax5.set_ylim(0,137)
ax5.set_xticks([54,56,58,60,62,64,66,68,70])
ax5.set_xticklabels(['54','56','58','60','62','64','66','68','70'],fontsize=18)
ax5.set_yticks([0,20,40,60,80,100,120])
ax5.set_yticklabels(['0','20','40','60','80','100','120'],fontsize=18)
legend = ax5.legend(ncols=3,handletextpad=-0.2,columnspacing=0,loc='upper right',bbox_to_anchor=(1.0,1.0),fontsize=14)
# fig5.savefig('Figure9c1.png', dpi=1200)

bar_y = [9,8,7,6,5,4,3,2,1]
s11_e2_Bo = [s11_e2_Bo_s8c1[5948],
             s11_e2_Bo_s8c2[5588],
             s11_e2_Bo_s8c3[5663],
             s11_e2_Bo_s8c4[5684],
             s11_e2_Bo_s8c5[7048],
             s11_e2_Bo_s8c6[6185],
             s11_e2_Bo_s8c7[6062],
             s11_e2_Bo_s8c8[5442],
             s11_e2_Bo_s8c9[5988]]
fig6,ax6 = plt.subplots(layout = 'constrained',figsize=(6,6.5)) # 9,5.4
ax6.yaxis.tick_right()
ax6.yaxis.set_label_position('right')
bh1 = ax6.barh(bar_y[7],s11_e2_Bo[0],align='center',height=0.45,linewidth=2,edgecolor='tab:blue',color='tab:blue')
bh2 = ax6.barh(bar_y[2],s11_e2_Bo[1],align='center',height=0.45,linewidth=2,edgecolor='tab:orange',color='tab:orange')
bh3 = ax6.barh(bar_y[1],s11_e2_Bo[2],align='center',height=0.45,linewidth=2,edgecolor='tab:green',color='tab:green')
bh4 = ax6.barh(bar_y[5],s11_e2_Bo[3],align='center',height=0.45,linewidth=2,edgecolor='tab:red',color='tab:red')
bh5 = ax6.barh(bar_y[8],s11_e2_Bo[4],align='center',height=0.45,linewidth=2,edgecolor='tab:purple',color='tab:purple')
bh6 = ax6.barh(bar_y[4],s11_e2_Bo[5],align='center',height=0.45,linewidth=2,edgecolor='tab:brown',color='tab:brown')
bh7 = ax6.barh(bar_y[6],s11_e2_Bo[6],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:pink',color='tab:pink')
bh8 = ax6.barh(bar_y[3],s11_e2_Bo[7],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:gray',color='tab:gray')
bh9 = ax6.barh(bar_y[0],s11_e2_Bo[8],align='center',height=0.30,linewidth=2,linestyle='--',edgecolor='tab:olive',color='tab:olive')
# ax6.bar_label(bh1,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax6.bar_label(bh2,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax6.bar_label(bh3,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax6.bar_label(bh4,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax6.bar_label(bh5,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax6.bar_label(bh6,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax6.bar_label(bh7,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax6.bar_label(bh8,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
# ax6.bar_label(bh9,fmt='%.1f',padding=6,fontsize=14,weight='normal',color='black')
ax6.bar_label(bh1,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[0]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax6.bar_label(bh2,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[1]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax6.bar_label(bh3,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[2]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax6.bar_label(bh4,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[3]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax6.bar_label(bh5,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[4]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax6.bar_label(bh6,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[5]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax6.bar_label(bh7,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[6]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax6.bar_label(bh8,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[7]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax6.bar_label(bh9,labels=[f"\N{MINUS SIGN}{abs(s11_e2_Bo[8]):.1f}"],padding=6,fontsize=14,weight='normal',color='black')
ax6.set_xlabel('Mid-plane stress $\sigma_{xx}$ (MPa) @ $v_{xx}^{max}$',fontsize=20)
# ax6.set_ylabel('Case',fontsize=20)
ax6.set_xlim(-503,0)
ax6.set_ylim(0,10)
ax6.set_xticks([-400,-300,-200,-100,0])
ax6.set_xticklabels(['\N{MINUS SIGN}400','\N{MINUS SIGN}300','\N{MINUS SIGN}200','\N{MINUS SIGN}100','0'],fontsize=18)
ax6.set_yticks([1,2,3,4,5,6,7,8,9])
ax6.set_yticklabels(['M-C-P','C-P-M','pure C','P-M-C','M-P-C','pure P','C-M-P','P-C-M','pure M'],fontsize=14)
# fig6.savefig('Figure9c2.png', dpi=1200)

# %%
# Find the time (array index) of the maximum velocity, and also apply to stress; for ABOVE
print(v1_n2_Bo_s8c1[0:6220].index(max(v1_n2_Bo_s8c1[0:6220])),'v =',max(v1_n2_Bo_s8c1[5300:6220]),'s =',s11_e2_Bo_s8c1[5948])
print(v1_n2_Bo_s8c2[0:5690].index(max(v1_n2_Bo_s8c2[0:5690])),'v =',max(v1_n2_Bo_s8c2[5300:5690]),'s =',s11_e2_Bo_s8c2[5588])
print(v1_n2_Bo_s8c3[0:5940].index(max(v1_n2_Bo_s8c3[0:5940])),'v =',max(v1_n2_Bo_s8c3[5300:5940]),'s =',s11_e2_Bo_s8c3[5663])
print(v1_n2_Bo_s8c4[0:5970].index(max(v1_n2_Bo_s8c4[0:5970])),'v =',max(v1_n2_Bo_s8c4[5300:5970]),'s =',s11_e2_Bo_s8c4[5684])
print(v1_n2_Bo_s8c5[0:7140].index(max(v1_n2_Bo_s8c5[0:7140])),'v =',max(v1_n2_Bo_s8c5[5300:7340]),'s =',s11_e2_Bo_s8c5[7048])
print(v1_n2_Bo_s8c6[0:6450].index(max(v1_n2_Bo_s8c6[0:6450])),'v =',max(v1_n2_Bo_s8c6[5300:6450]),'s =',s11_e2_Bo_s8c6[6185])
print(v1_n2_Bo_s8c7[0:6130].index(max(v1_n2_Bo_s8c7[0:6130])),'v =',max(v1_n2_Bo_s8c7[5300:6130]),'s =',s11_e2_Bo_s8c7[6062])
print(v1_n2_Bo_s8c8[0:5600].index(max(v1_n2_Bo_s8c8[0:5600])),'v =',max(v1_n2_Bo_s8c8[5300:5600]),'s =',s11_e2_Bo_s8c8[5442])
print(v1_n2_Bo_s8c9[0:6150].index(max(v1_n2_Bo_s8c9[0:6150])),'v =',max(v1_n2_Bo_s8c9[5300:6150]),'s =',s11_e2_Bo_s8c9[5988])
# Out:
# 5948 v = 70.064015625 s = -239.715499878
# 5588 v = 84.2364765625 s = -288.804656982
# 5663 v = 88.897890625 s = -305.527130127
# 5684 v = 75.3594453125 s = -257.527893066
# 7048 v = 39.1043203125 s = -111.490364075
# 6185 v = 78.0531484375 s = -267.118225098
# 6062 v = 74.8812890625 s = -254.651031494
# 5442 v = 80.4360390625 s = -275.552062988
# 5988 v = 93.630796875 s = -323.541625977
