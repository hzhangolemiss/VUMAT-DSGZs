# %%
import matplotlib.pyplot as plt

# Free surface velocity of Impactor ("stopper")
# 1. stage 1; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage1-case1-sq123_s2_50/abq_run/Job-1_v1_n1_Ip.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
v1_n1_Ip_s1c1 = [0.001*float(item[1]) for item in data2]

# 2. stage 3; case 1; CMP == 132
with open('../2_CPM_Comp_Impact/stage3-case1-sq132_s2_50/abq_run/Job-1_v1_n1_Ip.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Ip_s3c1 = [0.001*float(item[1]) for item in data2]

# 3. stage 3; case 2; PCM == 213
with open('../2_CPM_Comp_Impact/stage3-case2-sq213_s2_50/abq_run/Job-1_v1_n1_Ip.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Ip_s3c2 = [0.001*float(item[1]) for item in data2]

# 4. stage 3; case 3; PMC == 231
with open('../2_CPM_Comp_Impact/stage3-case3-sq231_s2_50/abq_run/Job-1_v1_n1_Ip.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Ip_s3c3 = [0.001*float(item[1]) for item in data2]

# 5. stage 3; case 4; MCP == 312
with open('../2_CPM_Comp_Impact/stage3-case4-sq312_s2_50/abq_run/Job-1_v1_n1_Ip.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Ip_s3c4 = [0.001*float(item[1]) for item in data2]

# 6. stage 3; case 5; MPC == 321
with open('../2_CPM_Comp_Impact/stage3-case5-sq321_s2_50/abq_run/Job-1_v1_n1_Ip.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Ip_s3c5 = [0.001*float(item[1]) for item in data2]

# Free surface velocity of Back
# 1. stage 1; case 1; CPM == 123
with open('../2_CPM_Comp_Impact/stage1-case1-sq123_s2_50/abq_run/Job-1_v1_n1_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
v1_n1_Bk_s1c1 = [0.001*float(item[1]) for item in data2]

# 2. stage 3; case 1; CMP == 132
with open('../2_CPM_Comp_Impact/stage3-case1-sq132_s2_50/abq_run/Job-1_v1_n1_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Bk_s3c1 = [0.001*float(item[1]) for item in data2]

# 3. stage 3; case 2; PCM == 213
with open('../2_CPM_Comp_Impact/stage3-case2-sq213_s2_50/abq_run/Job-1_v1_n1_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Bk_s3c2 = [0.001*float(item[1]) for item in data2]

# 4. stage 3; case 3; PMC == 231
with open('../2_CPM_Comp_Impact/stage3-case3-sq231_s2_50/abq_run/Job-1_v1_n1_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Bk_s3c3 = [0.001*float(item[1]) for item in data2]

# 5. stage 3; case 4; MCP == 312
with open('../2_CPM_Comp_Impact/stage3-case4-sq312_s2_50/abq_run/Job-1_v1_n1_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Bk_s3c4 = [0.001*float(item[1]) for item in data2]

# 6. stage 3; case 5; MPC == 321
with open('../2_CPM_Comp_Impact/stage3-case5-sq321_s2_50/abq_run/Job-1_v1_n1_Bk.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_Bk_s3c5 = [0.001*float(item[1]) for item in data2]

# Figure 6(a)
fig1,ax1 = plt.subplots(layout = 'constrained',figsize=(9,6.5)) # 9,5.4
ax1.plot(time[0:701],v1_n1_Ip_s1c1[0:701],linewidth=4,color='tab:pink',label='C as the $\\rm{1^{st}}$ layer')
#ax1.plot(time[0:5001],v1_n1_Ip_s3c1[0:5001],linewidth=2,color='tab:orange',label='CMP, 132')
ax1.plot(time[0:701],v1_n1_Ip_s3c2[0:701],linewidth=4,color='tab:olive',label='P as the $\\rm{1^{st}}$ layer')
#ax1.plot(time[0:5001],v1_n1_Ip_s3c3[0:5001],linewidth=2,color='tab:red',label='PMC, 231')
ax1.plot(time[0:701],v1_n1_Ip_s3c4[0:701],linewidth=4,color='tab:cyan',label='M as the $\\rm{1^{st}}$ layer')
#ax1.plot(time[0:5001],v1_n1_Ip_s3c5[0:5001],linewidth=2,color='tab:brown',label='MPC, 321')
ax1.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=20)
ax1.set_ylabel('Interface velocity $v_{xx}$ (m/s)',fontsize=20)
ax1.set_xlim(-0.2,7.2)
ax1.set_ylim(0,105)
ax1.set_xticks([0,1,2,3,4,5,6,7])
ax1.set_xticklabels(['0','1','2','3','4','5','6','7'],fontsize=18)
ax1.set_yticks([0,20,40,60,80,100])
ax1.set_yticklabels(['0','20','40','60','80','100'],fontsize=18)
legend = ax1.legend(loc='upper right',fontsize=16)
# fig1.savefig('Figure6a.png', dpi=1200)

# Figure 6(b)
fig2,ax2 = plt.subplots(layout = 'constrained',figsize=(9,6.5)) # 9,5.4
ax2.plot(time[600:1296],v1_n1_Bk_s1c1[600:1296],linewidth=4,color='tab:blue',label='C-P-M, steady: 35.6')
ax2.plot(time[600:1471],v1_n1_Bk_s3c1[600:1471],linewidth=4,color='tab:orange',label='C-M-P, steady: 54.3')
ax2.plot(time[600:1471],v1_n1_Bk_s3c2[600:1471],linewidth=4,color='tab:green',label='P-C-M, steady: 37.9')
ax2.plot(time[600:1471],v1_n1_Bk_s3c3[600:1471],linewidth=4,color='tab:red',label='P-M-C, steady: 44.2')
ax2.plot(time[600:1471],v1_n1_Bk_s3c4[600:1471],linewidth=4,color='tab:purple',label='M-C-P, steady: 52.3')
ax2.plot(time[600:1301],v1_n1_Bk_s3c5[600:1301],linewidth=4,color='tab:brown',label='M-P-C, steady: 45.1')
ax2.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=20)
ax2.set_ylabel('Free surface velocity $v_{xx}$ (m/s)',fontsize=20)
ax2.set_xlim(6,15)
ax2.set_ylim(0,56)
ax2.set_xticks([6,8,10,12,14])
ax2.set_xticklabels(['6','8','10','12','14'],fontsize=18)
ax2.set_yticks([0,10,20,30,40,50])
ax2.set_yticklabels(['0','10','20','30','40','50'],fontsize=18)
legend = ax2.legend(loc='lower right',fontsize=18)
# fig2.savefig('Figure6b.png', dpi=1200)
