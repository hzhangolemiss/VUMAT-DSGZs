# %%
import matplotlib.pyplot as plt

# 1. PC_1 @ 0.001/s; 348 K
exp_pc1_0_001_348K = [[0.0758446840886129, 58.1840470241594],
                      [0.1513471321246396, 48.1371077237479],
                      [0.2014314253437569, 45.3349001637692],
                      [0.2509141054311131, 44.0363161725595]]
exp_tep_pc1_0_001_348K = [float(item[0]) for item in exp_pc1_0_001_348K]
exp_tsig_pc1_0_001_348K = [float(item[1]) for item in exp_pc1_0_001_348K]
with open('../0_VUMAT_Validation/gDSGZ_PC_1_0.001_348K/abq_run_DTd/\
CubicElement-Radial_VUMAT_SNRwBiNUM_peeq_mises.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
abq_DTd_peeq_pc1_0_001_348K = [float(item[0]) for item in data2]
abq_DTd_mises_pc1_0_001_348K = [float(item[1]) for item in data2]

# 2. PMMA_1 @ 0.001/s; 300 K
exp_pmma1_0_001_300K = [[0.0506938225818147, 93.1102170797728],
                       [0.1016589833107149,105.3908391274348],
                       [0.1521587087818168,101.4562708985722],
                       [0.2024257166240197, 96.2101799267554],
                       [0.2508309834350299, 92.1563823576243],
                       [0.2990035326171409, 90.9640889549386],
                       [0.3499686933460411, 91.0833182952072]]
exp_tep_pmma1_0_001_300K = [float(item[0]) for item in exp_pmma1_0_001_300K]
exp_tsig_pmma1_0_001_300K = [float(item[1]) for item in exp_pmma1_0_001_300K]
with open('../0_VUMAT_Validation/gDSGZ_PMMA_1_0.001_300K/abq_run_DTd/\
CubicElement-Radial_VUMAT_SNRwBiNUM_peeq_mises.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
abq_DTd_peeq_pmma1_0_001_300K = [float(item[0]) for item in data2]
abq_DTd_mises_pmma1_0_001_300K = [float(item[1]) for item in data2]

# 3. PA-12 @ 100/s; 260 K
GSJ_pa12_100_0_260K = [[0.0994844921608725, 42.7817341329335],
                       [0.1985978565477543, 60.9294889592241],
                       [0.2994863856699236, 69.1718955337146],
                       [0.3983038892675908, 75.8236622429526],
                       [0.4959379497083996, 82.6200325763044],
                       [0.5947554533060669, 90.6455337146241]]
GSJ_tep_pa12_100_0_260K = [float(item[0]) for item in GSJ_pa12_100_0_260K]
GSJ_tsig_pa12_100_0_260K = [float(item[1]) for item in GSJ_pa12_100_0_260K]
with open('../0_VUMAT_Validation/gDSGZ_PA-12_100_260K/abq_run_DTd/\
CubicElement-Radial_VUMAT_SNRwBiNUM_peeq_mises.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
abq_DTd_peeq_pa12_100_0_260K = [float(item[0]) for item in data2]
abq_DTd_mises_pa12_100_0_260K = [float(item[1]) for item in data2]

# 4. ABS @ 1000/s; 273 K
exp_abs_1000_0_273K = [[0.0494055853169564,100.1700034956782],
                       [0.0994400939351477,121.0636273188745],
                       [0.1489786345343129,115.0445624277335],
                       [0.1995823112707238,109.4434103478050],
                       [0.2479571196806683,107.5960788648905],
                       [0.2973836193116807,106.7925210412938],
                       [0.3468638986074055,103.4855198252758],
                       [0.3973644976531152,102.6826342474880]]
exp_tep_abs_1000_0_273K = [float(item[0]) for item in exp_abs_1000_0_273K]
exp_tsig_abs_1000_0_273K = [float(item[1]) for item in exp_abs_1000_0_273K]
with open('../0_VUMAT_Validation/gDSGZ_ABS_1000_273K/abq_run_D/\
CubicElement-Radial_VUMAT_SNRwBiNUM_peeq_mises.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
abq_D_peeq_abs_1000_0_273K = [float(item[0]) for item in data2]
abq_D_mises_abs_1000_0_273K = [float(item[1]) for item in data2]

# 5. PBT @ 1000/s; 296 K
exp_pbt_1000_0_296K = [[0.0485808220493038, 76.0619086758538],
                       [0.0978095883753997,107.1240873284897],
                       [0.1453704981371603,104.0189043742238],
                       [0.1972630353789574,100.0821929314078],
                       [0.2458798543325274, 98.6441166059718],
                       [0.2955675811880179, 97.8314864921616],
                       [0.3463352151714952, 97.0193063396547],
                       [0.3960139428009191, 96.8316724761670],
                       [0.4456896706883207, 96.8523706961201]]
exp_tep_pbt_1000_0_296K = [float(item[0]) for item in exp_pbt_1000_0_296K]
exp_tsig_pbt_1000_0_296K = [float(item[1]) for item in exp_pbt_1000_0_296K]
with open('../0_VUMAT_Validation/gDSGZ_PBT_1000_296K/abq_run_D/\
CubicElement-Radial_VUMAT_SNRwBiNUM_peeq_mises.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
abq_D_peeq_pbt_1000_0_296K = [float(item[0]) for item in data2]
abq_D_mises_pbt_1000_0_296K = [float(item[1]) for item in data2]

# %%
# Figure 3(a)
fig1,ax1 = plt.subplots(layout = 'constrained',figsize=(9,6.5))
ax1.scatter(exp_tep_pc1_0_001_348K,exp_tsig_pc1_0_001_348K,marker='s',linewidth=2,s=180,color='none',edgecolors='tab:blue',zorder=1,label='PC_1, 0.001/s, 348 K; EXP')
ax1.plot(abq_DTd_peeq_pc1_0_001_348K[0:64],abq_DTd_mises_pc1_0_001_348K[0:64],linewidth=4,color='tab:blue',zorder=2,label='PC_1, 0.001/s, 348 K; FEM')
ax1.scatter(exp_tep_pmma1_0_001_300K,exp_tsig_pmma1_0_001_300K,marker='o',linewidth=2,s=180,color='none',edgecolors='tab:orange',zorder=1,label='PMMA_1, 0.001/s, 300 K; EXP')
ax1.plot(abq_DTd_peeq_pmma1_0_001_300K[0:68],abq_DTd_mises_pmma1_0_001_300K[0:68],linewidth=4,color='tab:orange',zorder=2,label='PMMA_1, 0.001/s, 300 K; FEM')
ax1.scatter(GSJ_tep_pa12_100_0_260K,GSJ_tsig_pa12_100_0_260K,marker='v',linewidth=2,s=180,color='none',edgecolors='tab:green',zorder=1,label='PA-12, 100/s, 260 K; EXP')
ax1.plot(abq_DTd_peeq_pa12_100_0_260K,abq_DTd_mises_pa12_100_0_260K,linewidth=4,color='tab:green',zorder=2,label='PA-12, 100/s, 260 K; FEM')
ax1.scatter(exp_tep_abs_1000_0_273K,exp_tsig_abs_1000_0_273K,marker='^',linewidth=2,s=180,color='none',edgecolors='tab:red',zorder=1,label='ABS, 1000/s, 273 K; EXP')
ax1.plot(abq_D_peeq_abs_1000_0_273K[0:75],abq_D_mises_abs_1000_0_273K[0:75],linewidth=4,color='tab:red',zorder=2,label='ABS, 1000/s, 273 K; FEM')
ax1.scatter(exp_tep_pbt_1000_0_296K,exp_tsig_pbt_1000_0_296K,marker='D',linewidth=2,s=180,color='none',edgecolors='tab:purple',zorder=1,label='PBT, 1000/s, 296 K; EXP')
ax1.plot(abq_D_peeq_pbt_1000_0_296K[0:82],abq_D_mises_pbt_1000_0_296K[0:82],linewidth=4,color='tab:purple',zorder=2,label='PBT, 1000/s, 296 K; FEM')
ax1.set_xlabel('Equivalent plastic strain $\\it{\\bar{\epsilon}^{pl}}$',fontsize=20)
ax1.set_ylabel('von Mises stress $\\it{\\bar{\sigma}}$ (MPa)',fontsize=20)
ax1.set_xlim(0,0.71)
ax1.set_ylim(0,125)
ax1.set_xticks([0,0.2,0.4,0.6])
ax1.set_xticklabels(['0','0.2','0.4','0.6'],fontsize=18)
ax1.set_yticks([0,40,80,120])
ax1.set_yticklabels(['0','40','80','120'],fontsize=18)
legend = ax1.legend(loc='lower right',fontsize=14)
# fig1.savefig('Figure3a.png', dpi=1200)

# %%
# 6. PC/ABS @ 1600/s; 293 K
exp_pcabs_1600_0_293K = [[0.0122427819307680, 27.8397711015737],
                         [0.0198546884193147, 40.8583690987124],
                         [0.0270482045855701, 51.6738197424893],
                         [0.0397647162562580, 63.4907010014306],
                         [0.0558842980483733, 74.5064377682404],
                         [0.0745756424465495, 78.5121602288984],
                         [0.1009305839980900, 78.5121602288984],
                         [0.1285674540371170, 76.3090128755365],
                         [0.1557755956208890, 75.3075822603720],
                         [0.1812773371401990, 76.3090128755365],
                         [0.2093289487487060, 77.5107296137339],
                         [0.2356796334219680, 78.9127324749642],
                         [0.2565018494615810, 81.1158798283262],
                         [0.2739222116307040, 83.7195994277539],
                         [0.2879492336858940, 83.9198855507868]]
exp_tep_pcabs_1600_0_293K = [float(item[0]) for item in exp_pcabs_1600_0_293K]
exp_tsig_pcabs_1600_0_293K = [float(item[1]) for item in exp_pcabs_1600_0_293K]
with open('../0_VUMAT_Validation/gDSGZ_PCABS_1600_293K/abq_run_D/\
CubicElement-Radial_VUMAT_SNRwBiNUM_peeq_mises.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
abq_D_peeq_pcabs_1600_0_293K = [float(item[0]) for item in data2]
abq_D_mises_pcabs_1600_0_293K = [float(item[1]) for item in data2]

# 7. PC/ABS @ 5000/s; 293 K
exp_pcabs_5000_0_293K = [[0.0046083747998887, 22.2317596566524],
                         [0.0113391074846562, 40.8583690987124],
                         [0.0193523767823777, 66.2947067238913],
                         [0.0328971553410900, 85.3218884120172],
                         [0.0545743957893393, 85.9227467811159],
                         [0.0707201269765978, 88.3261802575107],
                         [0.0924016243031262, 87.5250357653791],
                         [0.1166311673424460, 87.5250357653791],
                         [0.1480925384525340, 85.7224606580830],
                         [0.1897491330411290, 86.1230329041488],
                         [0.2233286051578160, 86.7238912732475],
                         [0.2577521554247070, 89.3276108726753],
                         [0.2959953417589120, 93.9341917024320],
                         [0.3253112462163190, 98.7410586552217],
                         [0.3495255861189280,103.7482117310440]]
exp_tep_pcabs_5000_0_293K = [float(item[0]) for item in exp_pcabs_5000_0_293K]
exp_tsig_pcabs_5000_0_293K = [float(item[1]) for item in exp_pcabs_5000_0_293K]
with open('../0_VUMAT_Validation/gDSGZ_PCABS_5000_293K/abq_run_D/\
CubicElement-Radial_VUMAT_SNRwBiNUM_peeq_mises.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
abq_D_peeq_pcabs_5000_0_293K = [float(item[0]) for item in data2]
abq_D_mises_pcabs_5000_0_293K = [float(item[1]) for item in data2]

# 8. PC_2 @ 4700/s; 298 K
exp_pc2015h_4700_0_298K = [[0.0047502047502047, 28.7223587223587],
                           [0.0094876694876694, 56.4127764127764],
                           [0.0149622349622349, 83.7592137592137],
                           [0.0233378833378833,105.2579852579850],
                           [0.0330712530712530,115.0614250614250],
                           [0.0501665301665301,120.5651105651100],
                           [0.0612758212758212,120.3931203931200],
                           [0.0812576212576212,118.6732186732180],
                           [0.1115879515879516,114.8894348894340],
                           [0.1411793611793612,111.2776412776410],
                           [0.1715333515333515,109.7297297297290],
                           [0.1922631722631723,108.6977886977880],
                           [0.2129984529984531,108.1818181818180],
                           [0.2330366730366730,111.7936117936110]]
exp_tep_pc2015h_4700_0_298K = [float(item[0]) for item in exp_pc2015h_4700_0_298K]
exp_tsig_pc2015h_4700_0_298K = [float(item[1]) for item in exp_pc2015h_4700_0_298K]
with open('../0_VUMAT_Validation/mDSGZ_PC_2_4700_298K/abq_run_D/\
CubicElement-Radial_VUMAT_SNRwBiNUM_peeq_mises.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
abq_D_peeq_pc2015h_4700_0_298K = [float(item[0]) for item in data2]
abq_D_mises_pc2015h_4700_0_298K = [float(item[1]) for item in data2]

# 9. PMMA_2 @ 1350/s; 298 K
exp_pmma2015h_1350_0_298K = [[0.0081437262876507, 62.5813348717690],
                             [0.0214691032080344,165.4794436089230],
                             [0.0347557256446786,241.9033956414410],
                             [0.0480035935975831,291.8531909693240],
                             [0.0656095794037534,318.9422448094310],
                             [0.0817235175859479,326.7762655210600],
                             [0.0948973997062586,326.1844889582750],
                             [0.1109857951605338,316.5696336600300],
                             [0.1401987488467238,272.6686205385550],
                             [0.1818448455435646,222.1584265679600],
                             [0.2344804807317551,178.8767145005620],
                             [0.3010457104731790,151.2492816107770],
                             [0.3412887187019010,142.2542778564360]]
exp_tep_pmma2015h_1350_0_298K = [float(item[0]) for item in exp_pmma2015h_1350_0_298K]
exp_tsig_pmma2015h_1350_0_298K = [float(item[1]) for item in exp_pmma2015h_1350_0_298K]
with open('../0_VUMAT_Validation/mDSGZ_PMMA_2_1350_298K/abq_run_D/\
CubicElement-Radial_VUMAT_SNRwBiNUM_peeq_mises.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
abq_D_peeq_pmma2015h_1350_0_298K = [float(item[0]) for item in data2]
abq_D_mises_pmma2015h_1350_0_298K = [float(item[1]) for item in data2]

# %%
# Figure 3(b)
fig2,ax2 = plt.subplots(layout = 'constrained',figsize=(9,6.5))
ax2.scatter(exp_tep_pcabs_1600_0_293K,exp_tsig_pcabs_1600_0_293K,marker='o',linewidth=2,s=180,color='none',edgecolors='tab:brown',zorder=1,label='PC/ABS, 1600/s, 293 K; EXP')
ax2.plot(abq_D_peeq_pcabs_1600_0_293K[0:43],abq_D_mises_pcabs_1600_0_293K[0:43],linewidth=4,color='tab:brown',zorder=2,label='PC/ABS, 1600/s, 293 K; FEM')
ax2.scatter(exp_tep_pcabs_5000_0_293K,exp_tsig_pcabs_5000_0_293K,marker='s',linewidth=2,s=180,color='none',edgecolors='tab:pink',zorder=1,label='PC/ABS, 5000/s, 293 K; EXP')
ax2.plot(abq_D_peeq_pcabs_5000_0_293K[0:66],abq_D_mises_pcabs_5000_0_293K[0:66],linewidth=4,color='tab:pink',zorder=2,label='PC/ABS, 5000/s, 293 K; FEM')
ax2.scatter(exp_tep_pc2015h_4700_0_298K,exp_tsig_pc2015h_4700_0_298K,marker='v',linewidth=2,s=180,color='none',edgecolors='tab:gray',zorder=1,label='PC_2, 4700/s, 298 K; EXP')
ax2.plot(abq_D_peeq_pc2015h_4700_0_298K[0:42],abq_D_mises_pc2015h_4700_0_298K[0:42],linewidth=4,color='tab:gray',zorder=2,label='PC_2, 4700/s, 298 K; FEM')
ax2.scatter(exp_tep_pmma2015h_1350_0_298K,exp_tsig_pmma2015h_1350_0_298K,marker='^',linewidth=2,s=180,color='none',edgecolors='tab:olive',zorder=1,label='PMMA_2, 1350/s, 298 K; EXP')
ax2.plot(abq_D_peeq_pmma2015h_1350_0_298K[0:66],abq_D_mises_pmma2015h_1350_0_298K[0:66],linewidth=4,color='tab:olive',zorder=2,label='PMMA_2, 1350/s, 298 K; FEM')
ax2.set_xlabel('Equivalent plastic strain $\\it{\\bar{\epsilon}^{pl}}$',fontsize=20)
ax2.set_ylabel('von Mises stress $\\it{\\bar{\sigma}}$ (MPa)',fontsize=20)
ax2.set_xlim(0,0.40)
ax2.set_ylim(0,350)
ax2.set_xticks([0,0.1,0.2,0.3])
ax2.set_xticklabels(['0','0.1','0.2','0.3'],fontsize=18)
ax2.set_yticks([0,100,200,300])
ax2.set_yticklabels(['0','100','200','300'],fontsize=18)
legend = ax2.legend(loc='upper right',fontsize=14)
# fig2.savefig('Figure3b.png', dpi=1200)
