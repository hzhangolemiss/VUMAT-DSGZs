# %%
import matplotlib.pyplot as plt

# V1 on Node 1
# PCABS @ 50 m/s; 47900/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_50/abq_run/Job-1_v1_n1.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
time = [1000000*float(item[0]) for item in data2]
v1_n1_pcabs_50 = [0.001*float(item[1]) for item in data2]

# PC_2 @ 50 m/s; 47750/s; 298 K
with open('../1_SingleLayer_Impact/mDSGZ-PC_2_50/abq_run/Job-1_v1_n1.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_pc2015h_50 = [0.001*float(item[1]) for item in data2]

# PMMA_2 @ 50 m/s; 46800/s; 298 K
with open('../1_SingleLayer_Impact/mDSGZ-PMMA_2_50/abq_run/Job-1_v1_n1.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_pmma2015h_50 = [0.001*float(item[1]) for item in data2]

# Al6061 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Al6061_50/abq_run/Job-1_v1_n1.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_al6061_50 = [0.001*float(item[1]) for item in data2]

# Steel4340 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Steel4340_50/abq_run/Job-1_v1_n1.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_steel4340_50 = [0.001*float(item[1]) for item in data2]

# SiC @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JH2-SiC_50/abq_run/Job-1_v1_n1.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
v1_n1_sic_50 = [0.001*float(item[1]) for item in data2]

# S11 on Element 2
# PCABS @ 50 m/s; 47900/s; 298 K
with open('../1_SingleLayer_Impact/gDSGZ-PCABS_50/abq_run/Job-1_s11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
ss1_e2_pcabs_50 = [float(item[1]) for item in data2]

# PC_2 @ 50 m/s; 47750/s; 298 K
with open('../1_SingleLayer_Impact/mDSGZ-PC_2_50/abq_run/Job-1_s11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
ss1_e2_pc2015h_50 = [float(item[1]) for item in data2]

# PMMA_2 @ 50 m/s; 46800/s; 298 K
with open('../1_SingleLayer_Impact/mDSGZ-PMMA_2_50/abq_run/Job-1_s11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
ss1_e2_pmma2015h_50 = [float(item[1]) for item in data2]

# Al6061 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Al6061_50/abq_run/Job-1_s11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
ss1_e2_al6061_50 = [float(item[1]) for item in data2]

# Steel4340 @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JCS-Steel4340_50/abq_run/Job-1_s11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
ss1_e2_steel4340_50 = [float(item[1]) for item in data2]

# SiC @ 50 m/s; ?/s; 298 K
with open('../1_SingleLayer_Impact/JH2-SiC_50/abq_run/Job-1_s11_e2.plot','r') as file:
    next(file)
    next(file)
    content = file.read()
    data1 = content.split('\n')
    data2 = []
    for i in range(len(data1)-1):
        data2.append(data1[i].split(' '))
ss1_e2_sic_50 = [float(item[1]) for item in data2]

# %%
# Figure 5(a)
fig1,ax1 = plt.subplots(layout = 'constrained',figsize=(9,6.5))
ax1.plot(time[0:326],v1_n1_pcabs_50[0:326],linewidth=4,color='tab:blue',label='PC/ABS')
ax1.plot(time[0:324],v1_n1_pc2015h_50[0:324],linewidth=4,color='tab:orange',label='PC_2')
ax1.plot(time[0:268],v1_n1_pmma2015h_50[0:268],linewidth=4,color='tab:green',label='PMMA_2')
ax1.plot(time[0:92],v1_n1_al6061_50[0:92],linewidth=4,color='tab:red',label='Al-6061')
ax1.plot(time[0:97],v1_n1_steel4340_50[0:97],linewidth=4,color='tab:purple',label='Steel-4340')
ax1.plot(time[0:67],v1_n1_sic_50[0:67],linewidth=4,color='tab:brown',label='SiC')
ax1.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=19)
ax1.set_ylabel('Free surface velocity $v_{xx}$ ($\\rm{m/s}$)',fontsize=19)
ax1.set_xlim(0,16.5)
ax1.set_ylim(0,105)
ax1.set_xticks([0,2,4,6,8,10,12,14,16])
ax1.set_xticklabels(['0','2','4','6','8','10','12','14','16'],fontsize=16)
ax1.set_yticks([0,20,40,60,80,100])
ax1.set_yticklabels(['0','20','40','60','80','100'],fontsize=16)
legend = ax1.legend(loc='lower right',fontsize=18)
fig1.savefig('Figure5a.png', dpi=1200)

# Figure 5(b)
fig2,ax2 = plt.subplots(layout = 'constrained',figsize=(9,6.5))
ax2.plot(time[0:175],ss1_e2_pcabs_50[0:175],linewidth=4,color='tab:blue',label='PCABS, 50 m/s')
ax2.plot(time[0:170],ss1_e2_pc2015h_50[0:170],linewidth=4,color='tab:orange',label='PCm, 50 m/s')
ax2.plot(time[0:140],ss1_e2_pmma2015h_50[0:140],linewidth=4,color='tab:green',label='PMMAm, 50 m/s')
ax2.plot(time[0:46],ss1_e2_al6061_50[0:46],linewidth=4,color='tab:red',label='Al6061, 50 m/s')
ax2.plot(time[0:50],ss1_e2_steel4340_50[0:50],linewidth=4,color='tab:purple',label='Steel4340, 50 m/s')
ax2.plot(time[0:33],ss1_e2_sic_50[0:33],linewidth=4,color='tab:brown',label='SiC, 50 m/s')
ax2.set_xlabel('Time ($\\rm{\mu s}$)',fontsize=19)
ax2.set_ylabel('Mid-plane stress $\sigma_{xx}$ (MPa)',fontsize=19)
ax2.set_xlim(0,9.2)
ax2.set_ylim(-1220,0)
ax2.set_xticks([0,2,4,6,8])
ax2.set_xticklabels(['0','2','4','6','8'],fontsize=16)
ax2.set_yticks([-1200,-1000,-800,-600,-400,-200,0])
ax2.set_yticklabels(['\N{MINUS SIGN}1200',
                     '\N{MINUS SIGN}1000',
                     '\N{MINUS SIGN}800',
                     '\N{MINUS SIGN}600',
                     '\N{MINUS SIGN}400',
                     '\N{MINUS SIGN}200','0'],fontsize=16)
# legend = ax2.legend(loc='lower right',fontsize=14)
# fig2.savefig('Figure5b.png', dpi=1200)

fig2s,ax2s = plt.subplots(layout = 'constrained',figsize=(9,6.5))
ax2s.plot(time[0:175],ss1_e2_pcabs_50[0:175],linewidth=6,color='tab:blue',label='PCABS, 50 m/s')
ax2s.plot(time[0:170],ss1_e2_pc2015h_50[0:170],linewidth=6,color='tab:orange',label='PCm, 50 m/s')
ax2s.plot(time[0:140],ss1_e2_pmma2015h_50[0:140],linewidth=6,color='tab:green',label='PMMAm, 50 m/s')
ax2s.set_xlim(1.6,8.8)
ax2s.set_ylim(-150,0)
ax2s.set_xticks([2,4,6,8])
ax2s.set_xticklabels(['2','4','6','8'],fontsize=28)
ax2s.set_yticks([-120,-80])
ax2s.set_yticklabels(['\N{MINUS SIGN}120','\N{MINUS SIGN}80'],fontsize=28)
# legend = ax2s.legend(loc='lower right',fontsize=14)
# fig2s.savefig('Figure5bs.png', dpi=1200)
# Out:
# [Text(0, -120, '−120'), Text(0, -80, '−80')]
